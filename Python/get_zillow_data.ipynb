# %%
# ZILLOW DATA EXTRACTION WRITTEN BY SONIA YANG

# Dependencies
import requests
import urllib
import random
import math
import pandas as pd
import xml.etree.ElementTree as ET
import time
from config import zws_id, gkey # please use your own Zillow & Google API keys!
from urllib.request import urlopen

# %%
# FUNCTION to grab the exact address based on longitude and latitude
# modified from here https://gist.github.com/bradmontgomery/5397472
# their example didn't include an API key, but I added it otherwise you'd hit the rate limit easily

def reverse_geocode(latitude, longitude):
    # Did the geocoding request comes from a device with a
    # location sensor? Must be either true or false
    sensor = 'true'

    # Hit Google's reverse geocoder directly
    # NOTE: I *think* their terms state that you're supposed to
    # use google maps if you use their api for anything.
    base = "https://maps.googleapis.com/maps/api/geocode/json?"
    params = "latlng={lat},{lon}&sensor={sen}&key={key}".format(
        lat=latitude,
        lon=longitude,
        sen=sensor,
        key=gkey
    )
    url = "{base}{params}".format(base=base, params=params)
    #print(url)
    response = requests.get(url).json()
    address = response['results'][0]['formatted_address']
    return address

# %%
# FUNCTION to generate random lat & lng within a certain radius 
# modified from here: http://hadoopguru.blogspot.com/2014/12/python-generate-random-latitude-and.html
# changed to take in an empty initial dataframe and load in the data + return it
# this calls the reverse geocode function to grab the addresses of each randomly generated lat & lng

def generate_addresses(latitude, longitude, df):
    
    radius = 10000                         #Choose your own radius
    radiusInDegrees=radius/111300            
    r = radiusInDegrees

    counter = 0
    
    for i in range(1,200):                 #Choose number of Lat Long to be generated

        u = float(random.uniform(0.0,1.0))
        v = float(random.uniform(0.0,1.0))

        w = r * math.sqrt(u)
        t = 2 * math.pi * v
        x = w * math.cos(t) 
        y = w * math.sin(t)

        xLat  = x + latitude
        yLng = y + longitude

        df.set_value(counter, "latitude", xLat)
        df.set_value(counter, "longitude", yLng)
        
        #print(format(counter) + ": " + format(xLat) + ", " + format(yLng))
        address = reverse_geocode(xLat, yLng).split(',')
        citystatezip = address[1] + address[2]
        
        df.set_value(counter, "address", address[0])
        df.set_value(counter, "city_state_zip", citystatezip)
        
        # Add to counter
        counter = counter + 1
    
    return df

# %%
# FUNCTION to call Zillow API's GetSearchResults and will check to see if a house exists at that address
# message code will be written to dataframe
# zillow url format
# http://www.zillow.com/webservice/GetSearchResults.htm?zws-id=<ZWSID>&address=2114+Bigelow+Ave&citystatezip=Seattle%2C+WA
        
def get_message_codes(df):

    for index, row in df.iterrows():

        try:
            url = 'https://www.zillow.com/webservice/GetSearchResults.htm?zws-id='
            address = row['address']
            citystatezip =row['city_state_zip']


            query_url = url + zws_id + '&address=' + urllib.parse.quote(address) + '&citystatezip=' + urllib.parse.quote(citystatezip) 
            #print(query_url)

            root = ET.parse(urlopen(query_url)).getroot()

            for message in root.iter('message'):
                message_code = message[1].text

            print(format(index) + ": " + message_code)

            df.set_value(index, 'message_code', message_code)

            time.sleep(0.5) #necessary bc bombarding Zillow with API calls doesn't allow enough time to respond to each

        except:
            break

# %%
# FUNCTION to call Zillow's GetDeepSearchResults and look up Zestimate, bed, and bath
# http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=<ZWSID>&address=2114+Bigelow+Ave&citystatezip=Seattle%2C+WA
# there are some limitations such as multiple zestimates depending on when the house was sold/if it was sold multiple times
# the code to handle that would get too convoluted so I am just writing in the most recent (according to the API) values
# probably not what we would do in real life
# but a decision we made re: the scope of a classroom project on a short time constraint

def search_zillow(df):
    
    for index, row in df.iterrows():
        try:
            url = 'https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id='
            address = df['address'][index]
            citystatezip = df['city_state_zip'][index]


            query_url = url + zws_id + '&address=' + urllib.parse.quote(address) + '&citystatezip=' + urllib.parse.quote(citystatezip) 


            root = ET.parse(urlopen(query_url)).getroot()

            print("row " + format(index) + ": " + address + citystatezip)
            print(query_url)

            '''
               "year built","lot size","finished sq ft"'''
            
            #zpid
            for zpid in root.iter('zpid'):
                df.set_value(index,'zpid', zpid.text)
            
            # we already have the address from the address + citystatezip variables
            # so we don't need to grab it again
            # same with lat & lng already being in the table
            
            #valuation (high and low)
            for valuation in root.iter('valuationRange'):
                highValuation = valuation[1].text
                lowValuation = valuation[0].text
                df.set_value(index, 'valuation_high', highValuation)
                df.set_value(index, 'valuation_low', lowValuation)
            
            #zestimate
            for zestimate in root.iter('zestimate'):
                zestimate_value = zestimate[0].text

                if zestimate_value is None:
                    print('not for sale')
                else:
                    print ('zestimate (value): ' + format(zestimate[0].text)) 
                    df.set_value(index, 'zestimate', zestimate_value)
             
            #home value index
            for zindexValue in root.iter('zindexValue'):
                df.set_value(index, 'home value index', zindexValue.text)
            
            #tax assessment
            for taxAssessment in root.iter('taxAssessment'):
                df.set_value(index, 'tax assessment', taxAssessment.text)
                
            #tax assessment year
            for taxAssessmentYear in root.iter('taxAssessmentYear'):
                df.set_value(index, 'tax assess year', taxAssessmentYear.text)
                
            #year built
            for yearBuilt in root.iter('yearBuilt'):
                df.set_value(index, 'year built', yearBuilt.text)
             
            #lot size sq ft
            for lotSizeSqFt in root.iter('lotSizeSqFt'):
                df.set_value(index, 'lot size', lotSizeSqFt.text)
            
            #finished sq ft
            for finishedSqFt in root.iter('finishedSqFt'):
                df.set_value(index, 'finished sq ft', finishedSqFt.text)
            
            #bedrooms
            for bedroom in root.iter('bedrooms'):
                bedrooms = bedroom.text
                #print("bedrooms: " + bedrooms)
                df.set_value(index, 'bedrooms', bedrooms)

            #bathrooms
            for bathroom in root.iter('bathrooms'):
                bathrooms = bathroom.text
                #print("bathrooms: " + bathrooms + "\n")
                df.set_value(index, 'bathrooms', bathrooms)           
            
            print('\n')

            time.sleep(0.5) 


        except:
            break

# %% [markdown]
# <h2>HOW TO RUN THIS CODE</h2>
# <ol>
# <li>Initialize an empty dataframe with the fields as marked below</li>
# <li>Call the <strong>generate_addresses</strong> function passing in your empty dataframe</li>
# <li>Call the <strong>get_message_codes</strong> to update your dataframe with message codes indicating whether or not a valid property exists at each address. <strong>IMPORTANT:</strong> please register your own Zillow account/get your own key for this!! If we all keep using the same one we'll easily hit the rate limit </li>
# <li>Drop the rows in the dataframe for which a property does not exist at that address</li>
# <li>Call the <strong>search_zillow</strong> function to get the zestimate (aka price of the property), # of bedrooms, and # of bathrooms</li>
# <li>I did not include it in my code, but once you get a sample size of data that you are satisfied with for the city, maybe write it out to a CSV so you don't have to keep running this code/can use it later</li>
# </ol>
#
# feel free to comment out my print statements while the functions are running if you find them distracting

# %%
# HOW TO RUN ALL THE FUNCTIONS, USING LOS ANGELES AS AN EXAMPLE

# coordinates taken from the CitiesGeo_Output.csv
# we should manually run the following code on each individual city instead of nesting it in another loop
# while this may be hardcoded, it's better than waiting on one gigantic loop that takes forever

# STEP 1: INITALIZE THE DATAFRAME
# if we need any more fields, let me know
la_df = pd.DataFrame({"zpid": '',
                      "address":'',
                      "city_state_zip":'',
                      "latitude":'',
                      "longitude":'',
                      "message_code":'',
                      "zestimate":'',
                      "valuation_high":'',
                      "valuation_low": '',
                      "home value index":'',
                      "tax assessment":'',
                      "tax assess year":'',
                      "year built":'',
                      "lot size":'',
                      "finished sq ft":'',
                      "bedrooms":'',
                      "bathrooms":''}, index=[0])

# reorder the columns
la_df = la_df[["zpid", "address","city_state_zip","latitude","longitude","message_code","zestimate",
               "valuation_high","valuation_low","home value index","tax assessment","tax assess year",
               "year built","lot size","finished sq ft","bedrooms","bathrooms"]]

# STEP 2: GENERATE RANDOM ADDRESSES IN THE DESIGNATED AREA
# pass in the coordinates for Los Angeles plus the empty dataframe
generate_addresses(34.0522342,-118.2436849, la_df) 

#la_df
# Out:
#     zpid                                            address  \
# 0                                      4651 Castle Crest Dr
# 1    NaN                                   3933 Ingraham St
# 2    NaN                                 3221 Fruitland Ave
# 3    NaN                                    4443 Verdugo Rd
# 4    NaN                                   1241 S Grand Ave
# 5    NaN                                 520 S Lucerne Blvd
# 6    NaN                                    638 Pheasant Dr
# 7    NaN                                  107 S Vermont Ave
# 8    NaN                           1847-1899 S San Pedro St
# 9    NaN                                   2301 S Hoover St
# 10   NaN                                  435 N Serrano Ave
# 11   NaN                                    2880 E Gage Ave
# 12   NaN                                    1305 Romulus Dr
# 13   NaN                                    4772 Academy St
# 14   NaN                                    4545 Toland Way
# 15   NaN                                  3529 La Clede Ave
# 16   NaN                             2820 E Washington Blvd
# 17   NaN                                  100-116 E 30th St
# 18   NaN                           635-637 Mt Washington Dr
# 19   NaN                                    3226 Lowell Ave
# 20   NaN                                      127 E 69th St
# 21   NaN                                1846-1852 W 42nd Pl
# 22   NaN                                 3160 California St
# 23   NaN                                      2017 Gates St
# 24   NaN                               3961-3965 Seneca Ave
# 25   NaN                    Women's and Children's Hospital
# 26   NaN                                    5830 Bickett St
# 27   NaN                        3985-3989 Bill Robertson Ln
# 28   NaN                                    4358 Kewanee St
# 29   NaN                          5048-5098 S St Andrews Pl
# ..   ...                                                ...
# 169  NaN                                 842 S Lucerne Blvd
# 170  NaN                              3406-3410 Atwater Ave
# 171  NaN                                       1009 56th St
# 172  NaN                                    1873 Academy Rd
# 173  NaN                                     2856 W 15th St
# 174  NaN                                  318 1/2 W 47th Pl
# 175  NaN                                     4498 Triggs St
# 176  NaN                                   1108b S Broadway
# 177  NaN                                    700 Park Row Dr
# 178  NaN                                    Riverside Trail
# 179  NaN                           1736-1744 N Van Ness Ave
# 180  NaN                                     1187 E 42nd St
# 181  NaN                                5525-5529 Bohlig Rd
# 182  NaN                                     2554 Grand Ave
# 183  NaN                               1025 Elysian Park Dr
# 184  NaN                              901-911 S Kingsley Dr
# 185  NaN  Christopher Columbus Transcontinental Hwy & I-...
# 186  NaN                                 1816 S Figueroa St
# 187  NaN                                    5519 Nordyke St
# 188  NaN                               1721 N North Main St
# 189  NaN  S Alameda St & I-10 & Christopher Columbus Tra...
# 190  NaN                                      155 W 69th St
# 191  NaN                                   2710 El Roble Dr
# 192  NaN                                  2219 Parkside Ave
# 193  NaN                                 4218 S Hobart Blvd
# 194  NaN                                   5418 Meridian St
# 195  NaN                                  705 Milwaukee Ave
# 196  NaN                                    6621 Wilson Ave
# 197  NaN                                     1215 Nadeau St
# 198  NaN                                 Vista Del Valle Dr
#
#                 city_state_zip latitude longitude message_code zestimate  \
# 0         Los Angeles CA 90041  34.1344  -118.223
# 1         Los Angeles CA 90005  34.0607  -118.312          NaN       NaN
# 2         Los Angeles CA 90058  33.9972   -118.21          NaN       NaN
# 3         Los Angeles CA 90065   34.132  -118.233          NaN       NaN
# 4         Los Angeles CA 90015  34.0395  -118.264          NaN       NaN
# 5         Los Angeles CA 90020  34.0646  -118.324          NaN       NaN
# 6         Los Angeles CA 90065  34.1042  -118.212          NaN       NaN
# 7         Los Angeles CA 90004  34.0724  -118.292          NaN       NaN
# 8         Los Angeles CA 90015   34.028  -118.257          NaN       NaN
# 9         Los Angeles CA 90007  34.0349  -118.284          NaN       NaN
# 10        Los Angeles CA 90004  34.0785  -118.307          NaN       NaN
# 11    Huntington Park CA 90255  33.9804  -118.218          NaN       NaN
# 12           Glendale CA 91205  34.1347  -118.237          NaN       NaN
# 13        Los Angeles CA 90032  34.0864  -118.182          NaN       NaN
# 14        Los Angeles CA 90041  34.1208  -118.218          NaN       NaN
# 15        Los Angeles CA 90039  34.1198  -118.257          NaN       NaN
# 16        Los Angeles CA 90023  34.0169  -118.219          NaN       NaN
# 17        Los Angeles CA 90011  34.0216   -118.27          NaN       NaN
# 18        Los Angeles CA 90065  34.0987  -118.217          NaN       NaN
# 19        Los Angeles CA 90032  34.0818  -118.162          NaN       NaN
# 20        Los Angeles CA 90003   33.977  -118.273          NaN       NaN
# 21        Los Angeles CA 90062  34.0062  -118.313          NaN       NaN
# 22    Huntington Park CA 90255  33.9708  -118.211          NaN       NaN
# 23        Los Angeles CA 90031  34.0682  -118.207          NaN       NaN
# 24        Los Angeles CA 90039  34.1261  -118.262          NaN       NaN
# 25        Los Angeles CA 90033  34.0615  -118.211          NaN       NaN
# 26    Huntington Park CA 90255  33.9897  -118.215          NaN       NaN
# 27        Los Angeles CA 90037  34.0125   -118.29          NaN       NaN
# 28        Los Angeles CA 90032  34.0765  -118.188          NaN       NaN
# 29        Los Angeles CA 90062  33.9971  -118.311          NaN       NaN
# ..                         ...      ...       ...          ...       ...
# 169       Los Angeles CA 90005  34.0594  -118.325          NaN       NaN
# 170       Los Angeles CA 90039  34.1168  -118.257          NaN       NaN
# 171       Los Angeles CA 90011  33.9921  -118.258          NaN       NaN
# 172       Los Angeles CA 90012  34.0801  -118.243          NaN       NaN
# 173       Los Angeles CA 90006  34.0454  -118.305          NaN       NaN
# 174       Los Angeles CA 90037       34  -118.279          NaN       NaN
# 175          Commerce CA 90040  34.0145  -118.174          NaN       NaN
# 176       Los Angeles CA 90015  34.0392  -118.259          NaN       NaN
# 177       Los Angeles CA 90012  34.0779  -118.232          NaN       NaN
# 178       Los Angeles CA 90027  34.1237  -118.291          NaN       NaN
# 179       Los Angeles CA 90028  34.1029  -118.316          NaN       NaN
# 180       Los Angeles CA 90011  34.0078  -118.255          NaN       NaN
# 181       Los Angeles CA 90032   34.072  -118.162          NaN       NaN
# 182   Huntington Park CA 90255  33.9689  -118.226          NaN       NaN
# 183       Los Angeles CA 90012   34.086  -118.236          NaN       NaN
# 184       Los Angeles CA 90006  34.0556  -118.303          NaN       NaN
# 185       Los Angeles CA 90007  34.0367  -118.292          NaN       NaN
# 186       Los Angeles CA 90015  34.0353  -118.271          NaN       NaN
# 187       Los Angeles CA 90042  34.1281  -118.197          NaN       NaN
# 188       Los Angeles CA 90012  34.0684  -118.225          NaN       NaN
# 189       Los Angeles CA 90021  34.0224   -118.24          NaN       NaN
# 190       Los Angeles CA 90003  33.9776  -118.275          NaN       NaN
# 191       Los Angeles CA 90041  34.1389  -118.224          NaN       NaN
# 192       Los Angeles CA 90031  34.0708  -118.201          NaN       NaN
# 193       Los Angeles CA 90062  34.0068  -118.307          NaN       NaN
# 194       Los Angeles CA 90042  34.1208  -118.198          NaN       NaN
# 195       Los Angeles CA 90042  34.1188  -118.192          NaN       NaN
# 196       Los Angeles CA 90001  33.9794  -118.238          NaN       NaN
# 197       Los Angeles CA 90001  33.9675  -118.253          NaN       NaN
# 198       Los Angeles CA 90027  34.1221  -118.284          NaN       NaN
#
#     valuation_high valuation_low home value index tax assessment  \
# 0
# 1              NaN           NaN              NaN            NaN
# 2              NaN           NaN              NaN            NaN
# 3              NaN           NaN              NaN            NaN
# 4              NaN           NaN              NaN            NaN
# 5              NaN           NaN              NaN            NaN
# 6              NaN           NaN              NaN            NaN
# 7              NaN           NaN              NaN            NaN
# 8              NaN           NaN              NaN            NaN
# 9              NaN           NaN              NaN            NaN
# 10             NaN           NaN              NaN            NaN
# 11             NaN           NaN              NaN            NaN
# 12             NaN           NaN              NaN            NaN
# 13             NaN           NaN              NaN            NaN
# 14             NaN           NaN              NaN            NaN
# 15             NaN           NaN              NaN            NaN
# 16             NaN           NaN              NaN            NaN
# 17             NaN           NaN              NaN            NaN
# 18             NaN           NaN              NaN            NaN
# 19             NaN           NaN              NaN            NaN
# 20             NaN           NaN              NaN            NaN
# 21             NaN           NaN              NaN            NaN
# 22             NaN           NaN              NaN            NaN
# 23             NaN           NaN              NaN            NaN
# 24             NaN           NaN              NaN            NaN
# 25             NaN           NaN              NaN            NaN
# 26             NaN           NaN              NaN            NaN
# 27             NaN           NaN              NaN            NaN
# 28             NaN           NaN              NaN            NaN
# 29             NaN           NaN              NaN            NaN
# ..             ...           ...              ...            ...
# 169            NaN           NaN              NaN            NaN
# 170            NaN           NaN              NaN            NaN
# 171            NaN           NaN              NaN            NaN
# 172            NaN           NaN              NaN            NaN
# 173            NaN           NaN              NaN            NaN
# 174            NaN           NaN              NaN            NaN
# 175            NaN           NaN              NaN            NaN
# 176            NaN           NaN              NaN            NaN
# 177            NaN           NaN              NaN            NaN
# 178            NaN           NaN              NaN            NaN
# 179            NaN           NaN              NaN            NaN
# 180            NaN           NaN              NaN            NaN
# 181            NaN           NaN              NaN            NaN
# 182            NaN           NaN              NaN            NaN
# 183            NaN           NaN              NaN            NaN
# 184            NaN           NaN              NaN            NaN
# 185            NaN           NaN              NaN            NaN
# 186            NaN           NaN              NaN            NaN
# 187            NaN           NaN              NaN            NaN
# 188            NaN           NaN              NaN            NaN
# 189            NaN           NaN              NaN            NaN
# 190            NaN           NaN              NaN            NaN
# 191            NaN           NaN              NaN            NaN
# 192            NaN           NaN              NaN            NaN
# 193            NaN           NaN              NaN            NaN
# 194            NaN           NaN              NaN            NaN
# 195            NaN           NaN              NaN            NaN
# 196            NaN           NaN              NaN            NaN
# 197            NaN           NaN              NaN            NaN
# 198            NaN           NaN              NaN            NaN
#
#     tax assess year year built lot size finished sq ft bedrooms bathrooms
# 0
# 1               NaN        NaN      NaN            NaN      NaN       NaN
# 2               NaN        NaN      NaN            NaN      NaN       NaN
# 3               NaN        NaN      NaN            NaN      NaN       NaN
# 4               NaN        NaN      NaN            NaN      NaN       NaN
# 5               NaN        NaN      NaN            NaN      NaN       NaN
# 6               NaN        NaN      NaN            NaN      NaN       NaN
# 7               NaN        NaN      NaN            NaN      NaN       NaN
# 8               NaN        NaN      NaN            NaN      NaN       NaN
# 9               NaN        NaN      NaN            NaN      NaN       NaN
# 10              NaN        NaN      NaN            NaN      NaN       NaN
# 11              NaN        NaN      NaN            NaN      NaN       NaN
# 12              NaN        NaN      NaN            NaN      NaN       NaN
# 13              NaN        NaN      NaN            NaN      NaN       NaN
# 14              NaN        NaN      NaN            NaN      NaN       NaN
# 15              NaN        NaN      NaN            NaN      NaN       NaN
# 16              NaN        NaN      NaN            NaN      NaN       NaN
# 17              NaN        NaN      NaN            NaN      NaN       NaN
# 18              NaN        NaN      NaN            NaN      NaN       NaN
# 19              NaN        NaN      NaN            NaN      NaN       NaN
# 20              NaN        NaN      NaN            NaN      NaN       NaN
# 21              NaN        NaN      NaN            NaN      NaN       NaN
# 22              NaN        NaN      NaN            NaN      NaN       NaN
# 23              NaN        NaN      NaN            NaN      NaN       NaN
# 24              NaN        NaN      NaN            NaN      NaN       NaN
# 25              NaN        NaN      NaN            NaN      NaN       NaN
# 26              NaN        NaN      NaN            NaN      NaN       NaN
# 27              NaN        NaN      NaN            NaN      NaN       NaN
# 28              NaN        NaN      NaN            NaN      NaN       NaN
# 29              NaN        NaN      NaN            NaN      NaN       NaN
# ..              ...        ...      ...            ...      ...       ...
# 169             NaN        NaN      NaN            NaN      NaN       NaN
# 170             NaN        NaN      NaN            NaN      NaN       NaN
# 171             NaN        NaN      NaN            NaN      NaN       NaN
# 172             NaN        NaN      NaN            NaN      NaN       NaN
# 173             NaN        NaN      NaN            NaN      NaN       NaN
# 174             NaN        NaN      NaN            NaN      NaN       NaN
# 175             NaN        NaN      NaN            NaN      NaN       NaN
# 176             NaN        NaN      NaN            NaN      NaN       NaN
# 177             NaN        NaN      NaN            NaN      NaN       NaN
# 178             NaN        NaN      NaN            NaN      NaN       NaN
# 179             NaN        NaN      NaN            NaN      NaN       NaN
# 180             NaN        NaN      NaN            NaN      NaN       NaN
# 181             NaN        NaN      NaN            NaN      NaN       NaN
# 182             NaN        NaN      NaN            NaN      NaN       NaN
# 183             NaN        NaN      NaN            NaN      NaN       NaN
# 184             NaN        NaN      NaN            NaN      NaN       NaN
# 185             NaN        NaN      NaN            NaN      NaN       NaN
# 186             NaN        NaN      NaN            NaN      NaN       NaN
# 187             NaN        NaN      NaN            NaN      NaN       NaN
# 188             NaN        NaN      NaN            NaN      NaN       NaN
# 189             NaN        NaN      NaN            NaN      NaN       NaN
# 190             NaN        NaN      NaN            NaN      NaN       NaN
# 191             NaN        NaN      NaN            NaN      NaN       NaN
# 192             NaN        NaN      NaN            NaN      NaN       NaN
# 193             NaN        NaN      NaN            NaN      NaN       NaN
# 194             NaN        NaN      NaN            NaN      NaN       NaN
# 195             NaN        NaN      NaN            NaN      NaN       NaN
# 196             NaN        NaN      NaN            NaN      NaN       NaN
# 197             NaN        NaN      NaN            NaN      NaN       NaN
# 198             NaN        NaN      NaN            NaN      NaN       NaN
#
# [199 rows x 17 columns]

# %%
# STEP 3: CALL THE ZILLOW API TO GET MESSAGE CODES
# 0 means there is a valid property at that address
# 508 and anything else means there isn't
# if you get nothing but invalid message codes, re-run STEP 2
# you might have to sign up for a new Zillow account if you keep getting invalid results here
# there is a possibility you hit the rate limit

get_message_codes(la_df)
# Out:
# 0: 0
# 1: 508
# 2: 508
# 3: 0
# 4: 508
# 5: 0
# 6: 0
# 7: 508
# 8: 508
# 9: 0
# 10: 508
# 11: 0
# 12: 0
# 13: 0
# 14: 508
# 15: 0
# 16: 508
# 17: 508
# 18: 508
# 19: 0
# 20: 508
# 21: 508
# 22: 0
# 23: 508
# 24: 508
# 25: 508
# 26: 508
# 27: 508
# 28: 508
# 29: 508
# 30: 508
# 31: 508
# 32: 0
# 33: 0
# 34: 508
# 35: 508
# 36: 508
# 37: 0
# 38: 508
# 39: 508
# 40: 0
# 41: 508
# 42: 0
# 43: 0
# 44: 508
# 45: 508
# 46: 0
# 47: 0
# 48: 0
# 49: 508
# 50: 508
# 51: 508
# 52: 0
# 53: 0
# 54: 508
# 55: 508
# 56: 508
# 57: 508
# 58: 508
# 59: 508
# 188  NaN     1721 N North Main St       Los Angeles CA 90012  34.0684
# 191  NaN         2710 El Roble Dr       Los Angeles CA 90041  34.1389
# 192  NaN        2219 Parkside Ave       Los Angeles CA 90031  34.0708
# 193  NaN       4218 S Hobart Blvd       Los Angeles CA 90062  34.0068
# 194  NaN         5418 Meridian St       Los Angeles CA 90042  34.1208
# 195  NaN        705 Milwaukee Ave       Los Angeles CA 90042  34.1188
#
#     longitude message_code zestimate valuation_high valuation_low  \
# 0    -118.223            0
# 3    -118.233            0       NaN            NaN           NaN
# 5    -118.324            0       NaN            NaN           NaN
# 6    -118.212            0       NaN            NaN           NaN
# 9    -118.284            0       NaN            NaN           NaN
# 11   -118.218            0       NaN            NaN           NaN
# 12   -118.237            0       NaN            NaN           NaN
# 13   -118.182            0       NaN            NaN           NaN
# 15   -118.257            0       NaN            NaN           NaN
# 19   -118.162            0       NaN            NaN           NaN
# 22   -118.211            0       NaN            NaN           NaN
# 32   -118.195            0       NaN            NaN           NaN
# 33   -118.227            0       NaN            NaN           NaN
# 37   -118.187            0       NaN            NaN           NaN
# 40   -118.222            0       NaN            NaN           NaN
# 42   -118.282            0       NaN            NaN           NaN
# 43   -118.285            0       NaN            NaN           NaN
# 46   -118.222            0       NaN            NaN           NaN
# 47   -118.188            0       NaN            NaN           NaN
# 48   -118.306            0       NaN            NaN           NaN
# 52   -118.282            0       NaN            NaN           NaN
# 53   -118.302            0       NaN            NaN           NaN
# 64   -118.321            0       NaN            NaN           NaN
# 67   -118.254            0       NaN            NaN           NaN
# 69   -118.318            0       NaN            NaN           NaN
# 74   -118.267            0       NaN            NaN           NaN
# 77   -118.307            0       NaN            NaN           NaN
# 78   -118.211            0       NaN            NaN           NaN
# 79   -118.236            0       NaN            NaN           NaN
# 80    -118.29            0       NaN            NaN           NaN
# ..        ...          ...       ...            ...           ...
# 120  -118.296            0       NaN            NaN           NaN
# 122  -118.267            0       NaN            NaN           NaN
# 125  -118.172            0       NaN            NaN           NaN
# 128  -118.231            0       NaN            NaN           NaN
# 129  -118.246            0       NaN            NaN           NaN
# 132  -118.307            0       NaN            NaN           NaN
# 135  -118.241            0       NaN            NaN           NaN
# 140  -118.281            0       NaN            NaN           NaN
# 145   -118.31            0       NaN            NaN           NaN
# 148  -118.268            0       NaN            NaN           NaN
# 149  -118.298            0       NaN            NaN           NaN
# 154  -118.182            0       NaN            NaN           NaN
# 155  -118.232            0       NaN            NaN           NaN
# 159  -118.305            0       NaN            NaN           NaN
# 165  -118.286            0       NaN            NaN           NaN
# 166  -118.326            0       NaN            NaN           NaN
# 169  -118.325            0       NaN            NaN           NaN
# 171  -118.258            0       NaN            NaN           NaN
# 173  -118.305            0       NaN            NaN           NaN
# 175  -118.174            0       NaN            NaN           NaN
# 176  -118.259            0       NaN            NaN           NaN
# 177  -118.232            0       NaN            NaN           NaN
# 180  -118.255            0       NaN            NaN           NaN
# 182  -118.226            0       NaN            NaN           NaN
# 188  -118.225            0       NaN            NaN           NaN
# 193              NaN            NaN             NaN        NaN      NaN
# 194              NaN            NaN             NaN        NaN      NaN
# 195              NaN            NaN             NaN        NaN      NaN
#
#     finished sq ft bedrooms bathrooms
# 0
# 3              NaN      NaN       NaN
# 5              NaN      NaN       NaN
# 6              NaN      NaN       NaN
# 9              NaN      NaN       NaN
# 11             NaN      NaN       NaN
# 12             NaN      NaN       NaN
# 13             NaN      NaN       NaN
# 15             NaN      NaN       NaN
# 19             NaN      NaN       NaN
# 22             NaN      NaN       NaN
# 32             NaN      NaN       NaN
# 33             NaN      NaN       NaN
# 37             NaN      NaN       NaN
# 40             NaN      NaN       NaN
# 42             NaN      NaN       NaN
# 43             NaN      NaN       NaN
# 46             NaN      NaN       NaN
# 47             NaN      NaN       NaN
# 48             NaN      NaN       NaN
# 52             NaN      NaN       NaN
# 53             NaN      NaN       NaN
# 64             NaN      NaN       NaN
# 67             NaN      NaN       NaN
# 69             NaN      NaN       NaN
# 74             NaN      NaN       NaN
# 77             NaN      NaN       NaN
# 78             NaN      NaN       NaN
# 79             NaN      NaN       NaN
# 80             NaN      NaN       NaN
# ..             ...      ...       ...
# 120            NaN      NaN       NaN
# 122            NaN      NaN       NaN
# 125            NaN      NaN       NaN
# 128            NaN      NaN       NaN
# 129            NaN      NaN       NaN
# 132            NaN      NaN       NaN
# 135            NaN      NaN       NaN
# 140            NaN      NaN       NaN
# 145            NaN      NaN       NaN
# 148            NaN      NaN       NaN
# 149            NaN      NaN       NaN
# 154            NaN      NaN       NaN
# 155            NaN      NaN       NaN
# 159            NaN      NaN       NaN
# 165            NaN      NaN       NaN
# 166            NaN      NaN       NaN
# 169            NaN      NaN       NaN
# 171            NaN      NaN       NaN
# 173            NaN      NaN       NaN
# 175            NaN      NaN       NaN
# 176            NaN      NaN       NaN
# 177            NaN      NaN       NaN
# 180            NaN      NaN       NaN
# 182            NaN      NaN       NaN
# 188            NaN      NaN       NaN
# 191            NaN      NaN       NaN
# 192            NaN      NaN       NaN
# 193            NaN      NaN       NaN
# 194            NaN      NaN       NaN
# 195            NaN      NaN       NaN
#
# [70 rows x 17 columns]

# %%
# STEP 5: SEARCH ZILLOW AND GET ZESTIMATE, BEDROOMS, & BATHROOMS
# fill the dataframe with the data

search_zillow(la_df)
la_df
# Out:
# row 0: 4651 Castle Crest Dr Los Angeles CA 90041
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4651%20Castle%20Crest%20Dr&citystatezip=%20Los%20Angeles%20CA%2090041
# zestimate (value): 720784
#
#
# row 3: 4443 Verdugo Rd Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4443%20Verdugo%20Rd&citystatezip=%20Los%20Angeles%20CA%2090065
# zestimate (value): 835577
#
#
# row 5: 520 S Lucerne Blvd Los Angeles CA 90020
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=520%20S%20Lucerne%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090020
# zestimate (value): 3521935
#
#
# row 6: 638 Pheasant Dr Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=638%20Pheasant%20Dr&citystatezip=%20Los%20Angeles%20CA%2090065
# zestimate (value): 890593
#
#
# row 9: 2301 S Hoover St Los Angeles CA 90007
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2301%20S%20Hoover%20St&citystatezip=%20Los%20Angeles%20CA%2090007
# zestimate (value): 789439
#
#
# row 11: 2880 E Gage Ave Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2880%20E%20Gage%20Ave&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 479455
# zestimate (value): 421606
# zestimate (value): 479928
# zestimate (value): 479526
# zestimate (value): 414420
# not for sale
# not for sale
# zestimate (value): 479685
# zestimate (value): 479690
# not for sale
# zestimate (value): 480865
# zestimate (value): 737775
# zestimate (value): 479472
# not for sale
# not for sale
# not for sale
# not for sale
# not for sale
# zestimate (value): 479465
# zestimate (value): 477877
#
#
# row 12: 1305 Romulus Dr Glendale CA 91205
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1305%20Romulus%20Dr&citystatezip=%20Glendale%20CA%2091205
# zestimate (value): 993876
#
#
# row 13: 4772 Academy St Los Angeles CA 90032
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4772%20Academy%20St&citystatezip=%20Los%20Angeles%20CA%2090032
# zestimate (value): 531241
#
#
# row 15: 3529 La Clede Ave Los Angeles CA 90039
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3529%20La%20Clede%20Ave&citystatezip=%20Los%20Angeles%20CA%2090039
# zestimate (value): 809011
#
#
# row 19: 3226 Lowell Ave Los Angeles CA 90032
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3226%20Lowell%20Ave&citystatezip=%20Los%20Angeles%20CA%2090032
# zestimate (value): 776066
#
#
# row 22: 3160 California St Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3160%20California%20St&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 423525
#
#
# row 32: 1118 Calzona St Los Angeles CA 90023
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1118%20Calzona%20St&citystatezip=%20Los%20Angeles%20CA%2090023
# zestimate (value): 374335
#
#
# row 33: 6811 Rugby Ave Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=6811%20Rugby%20Ave&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 491407
#
#
# row 37: 4501 Richelieu Terrace Los Angeles CA 90032
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4501%20Richelieu%20Terrace&citystatezip=%20Los%20Angeles%20CA%2090032
# zestimate (value): 581694
#
#
# row 40: 5002 Sierra Villa Dr Los Angeles CA 90041
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=5002%20Sierra%20Villa%20Dr&citystatezip=%20Los%20Angeles%20CA%2090041
# zestimate (value): 847495
#
#
# row 42: 835 Maltman Ave Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=835%20Maltman%20Ave&citystatezip=%20Los%20Angeles%20CA%2090026
# not for sale
#
#
# row 43: 632 W 43rd St Los Angeles CA 90037
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=632%20W%2043rd%20St&citystatezip=%20Los%20Angeles%20CA%2090037
# zestimate (value): 461964
#
#
# row 46: 1801 Sunny Heights Dr Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1801%20Sunny%20Heights%20Dr&citystatezip=%20Los%20Angeles%20CA%2090065
# zestimate (value): 974104
#
#
# row 47: 6013 Meridian St Los Angeles CA 90042
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=6013%20Meridian%20St&citystatezip=%20Los%20Angeles%20CA%2090042
# zestimate (value): 720866
#
#
# row 48: 5274 Los Caballeros Way Los Angeles CA 90027
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=5274%20Los%20Caballeros%20Way&citystatezip=%20Los%20Angeles%20CA%2090027
# zestimate (value): 2444769
#
#
# row 52: 3899 Amesbury Rd Los Angeles CA 90027
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3899%20Amesbury%20Rd&citystatezip=%20Los%20Angeles%20CA%2090027
# zestimate (value): 2578615
#
#
# row 53: 723 N Ardmore Ave Los Angeles CA 90029
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=723%20N%20Ardmore%20Ave&citystatezip=%20Los%20Angeles%20CA%2090029
# zestimate (value): 1443881
#
#
# row 64: 3849 3rd Ave Los Angeles CA 90008
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3849%203rd%20Ave&citystatezip=%20Los%20Angeles%20CA%2090008
# zestimate (value): 716541
# zestimate (value): 698348
#
#
# row 67: 1151 E 22nd St Los Angeles CA 90011
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1151%20E%2022nd%20St&citystatezip=%20Los%20Angeles%20CA%2090011
# zestimate (value): 593004
#
#
# row 69: 622 N Irving Blvd Los Angeles CA 90004
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=622%20N%20Irving%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090004
# not for sale
#
#
# row 74: 2822 W Silver Lake Dr Los Angeles CA 90039
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2822%20W%20Silver%20Lake%20Dr&citystatezip=%20Los%20Angeles%20CA%2090039
# zestimate (value): 1272999
#
#
# row 77: 1716 W 58th St Los Angeles CA 90062
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1716%20W%2058th%20St&citystatezip=%20Los%20Angeles%20CA%2090062
# zestimate (value): 390015
#
#
# row 78: 3164 Walnut St Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3164%20Walnut%20St&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 366366
#
#
# row 79: 2331 W Ave 31 Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2331%20W%20Ave%2031&citystatezip=%20Los%20Angeles%20CA%2090065
# not for sale
#
#
# row 80: 938 W 46th St Los Angeles CA 90037
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=938%20W%2046th%20St&citystatezip=%20Los%20Angeles%20CA%2090037
# zestimate (value): 547460
#
#
# row 86: 3941 S Van Ness Ave Los Angeles CA 90062
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3941%20S%20Van%20Ness%20Ave&citystatezip=%20Los%20Angeles%20CA%2090062
# zestimate (value): 619272
#
#
# row 88: 815 E Windsor Rd Glendale CA 91205
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=815%20E%20Windsor%20Rd&citystatezip=%20Glendale%20CA%2091205
# zestimate (value): 786735
#
#
# row 95: 3317 Carlyle St Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3317%20Carlyle%20St&citystatezip=%20Los%20Angeles%20CA%2090065
# zestimate (value): 765370
# row 98: 331 S Ave 57 Los Angeles CA 90042
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=331%20S%20Ave%2057&citystatezip=%20Los%20Angeles%20CA%2090042
# zestimate (value): 1021369
# zestimate (value): 815420
#
#
# row 103: 1706 W Jefferson Blvd Los Angeles CA 90018
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1706%20W%20Jefferson%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090018
# zestimate (value): 796701
#
#
# row 104: 152 S Lucerne Blvd Los Angeles CA 90004
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=152%20S%20Lucerne%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090004
# zestimate (value): 1605474
#
#
# row 105: 3400 Carnation Ave Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3400%20Carnation%20Ave&citystatezip=%20Los%20Angeles%20CA%2090026
# zestimate (value): 1705076
#
#
# row 108: 1159 E 80th St Los Angeles CA 90001
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1159%20E%2080th%20St&citystatezip=%20Los%20Angeles%20CA%2090001
# zestimate (value): 458288
# zestimate (value): 409640
#
#
# row 110: 3211 Sagamore Way Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3211%20Sagamore%20Way&citystatezip=%20Los%20Angeles%20CA%2090065
# zestimate (value): 903762
#
#
# row 116: 2720 California St Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2720%20California%20St&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 502555
#
#
# row 120: 695 S Catalina St Los Angeles CA 90005
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=695%20S%20Catalina%20St&citystatezip=%20Los%20Angeles%20CA%2090005
# not for sale
#
#
# row 122: 411 E 68th St Los Angeles CA 90003
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=411%20E%2068th%20St&citystatezip=%20Los%20Angeles%20CA%2090003
# zestimate (value): 328835
#
#
# row 125: 2201 Lafler Rd Los Angeles CA 90032
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2201%20Lafler%20Rd&citystatezip=%20Los%20Angeles%20CA%2090032
# zestimate (value): 789060
#
#
# row 128: 4116 W Ave 40 Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4116%20W%20Ave%2040&citystatezip=%20Los%20Angeles%20CA%2090065
# zestimate (value): 928754
#
#
# row 129: 1521 E 21st St Los Angeles CA 90011
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1521%20E%2021st%20St&citystatezip=%20Los%20Angeles%20CA%2090011
# zestimate (value): 439035
#
#
# row 132: 4946 W Melrose Hill Los Angeles CA 90029
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4946%20W%20Melrose%20Hill&citystatezip=%20Los%20Angeles%20CA%2090029
# zestimate (value): 1041407
#
#
# row 135: 1625 Riverside Dr Los Angeles CA 90031
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1625%20Riverside%20Dr&citystatezip=%20Los%20Angeles%20CA%2090031
# zestimate (value): 669307
# zestimate (value): 521372
# zestimate (value): 672862
# zestimate (value): 521865
# zestimate (value): 520326
# zestimate (value): 532690
#
#
# row 140: 905 Maltman Ave Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=905%20Maltman%20Ave&citystatezip=%20Los%20Angeles%20CA%2090026
# zestimate (value): 779955
#
#
# row 145: 2030 W 28th St Los Angeles CA 90018
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2030%20W%2028th%20St&citystatezip=%20Los%20Angeles%20CA%2090018
# zestimate (value): 657009
#
#
# row 148: 4341 Perlita Ave Los Angeles CA 90039
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4341%20Perlita%20Ave&citystatezip=%20Los%20Angeles%20CA%2090039
# zestimate (value): 1684002
#
#
# row 149: 5951 Raymond Ave Los Angeles CA 90044
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=5951%20Raymond%20Ave&citystatezip=%20Los%20Angeles%20CA%2090044
# zestimate (value): 430815
#
#
# row 154: 4736 Druid St Los Angeles CA 90032
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4736%20Druid%20St&citystatezip=%20Los%20Angeles%20CA%2090032
# zestimate (value): 588779
#
#
# row 155: 2317 S Santa Fe Ave Los Angeles CA 90058
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2317%20S%20Santa%20Fe%20Ave&citystatezip=%20Los%20Angeles%20CA%2090058
# zestimate (value): 395155
#
#
# row 159: 814 N Melrose Hill Los Angeles CA 90029
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=814%20N%20Melrose%20Hill&citystatezip=%20Los%20Angeles%20CA%2090029
# zestimate (value): 1024511
#
#
# row 165: 726 W 42nd Pl Los Angeles CA 90037
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=726%20W%2042nd%20Pl&citystatezip=%20Los%20Angeles%20CA%2090037
# zestimate (value): 523748
#
#
# row 166: 161S S Arden Blvd Los Angeles CA 90004
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=161S%20S%20Arden%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090004
# zestimate (value): 2294536
#
#
# row 169: 842 S Lucerne Blvd Los Angeles CA 90005
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=842%20S%20Lucerne%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090005
# zestimate (value): 1351067
#
#
# row 171: 1009 56th St Los Angeles CA 90011
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1009%2056th%20St&citystatezip=%20Los%20Angeles%20CA%2090011
# zestimate (value): 372624
#
#
# row 173: 2856 W 15th St Los Angeles CA 90006
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2856%20W%2015th%20St&citystatezip=%20Los%20Angeles%20CA%2090006
# zestimate (value): 817744
#
#
# row 175: 4498 Triggs St Commerce CA 90040
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4498%20Triggs%20St&citystatezip=%20Commerce%20CA%2090040
# zestimate (value): 477547
#
#
# row 176: 1108b S Broadway Los Angeles CA 90015
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1108b%20S%20Broadway&citystatezip=%20Los%20Angeles%20CA%2090015
# not for sale
#
#
# row 177: 700 Park Row Dr Los Angeles CA 90012
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=700%20Park%20Row%20Dr&citystatezip=%20Los%20Angeles%20CA%2090012
# not for sale
#
#
# row 180: 1187 E 42nd St Los Angeles CA 90011
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1187%20E%2042nd%20St&citystatezip=%20Los%20Angeles%20CA%2090011
# zestimate (value): 381615
#
#
# row 182: 2554 Grand Ave Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2554%20Grand%20Ave&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 464550
#
#
# row 188: 1721 N North Main St Los Angeles CA 90012
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1721%20N%20North%20Main%20St&citystatezip=%20Los%20Angeles%20CA%2090012
# not for sale
#
#
# row 191: 2710 El Roble Dr Los Angeles CA 90041
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2710%20El%20Roble%20Dr&citystatezip=%20Los%20Angeles%20CA%2090041
# zestimate (value): 788503
#
#
# row 192: 2219 Parkside Ave Los Angeles CA 90031
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2219%20Parkside%20Ave&citystatezip=%20Los%20Angeles%20CA%2090031
# zestimate (value): 631704
# row 193: 4218 S Hobart Blvd Los Angeles CA 90062
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4218%20S%20Hobart%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090062
# zestimate (value): 496420
#
#
# row 194: 5418 Meridian St Los Angeles CA 90042
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=5418%20Meridian%20St&citystatezip=%20Los%20Angeles%20CA%2090042
# zestimate (value): 677017
#
#
# row 195: 705 Milwaukee Ave Los Angeles CA 90042
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=705%20Milwaukee%20Ave&citystatezip=%20Los%20Angeles%20CA%2090042
# zestimate (value): 744632
#            zpid                  address             city_state_zip latitude  \
# 0      20850860     4651 Castle Crest Dr       Los Angeles CA 90041  34.1344
# 3      20848463          4443 Verdugo Rd       Los Angeles CA 90065   34.132
# 5      20775277       520 S Lucerne Blvd       Los Angeles CA 90020  34.0646
# 6      20760983          638 Pheasant Dr       Los Angeles CA 90065  34.1042
# 9    2111194430         2301 S Hoover St       Los Angeles CA 90007  34.0349
# 11     62018650          2880 E Gage Ave   Huntington Park CA 90255  33.9804
# 12     20848238          1305 Romulus Dr          Glendale CA 91205  34.1347
# 13     20639008          4772 Academy St       Los Angeles CA 90032  34.0864
# 15     20750599        3529 La Clede Ave       Los Angeles CA 90039  34.1198
# 19    125242705          3226 Lowell Ave       Los Angeles CA 90032  34.0818
# 22     21030425       3160 California St   Huntington Park CA 90255  33.9708
# 22             996        2       1.0
# 32             756        2       1.0
# 33            2252        2       1.5
# 37            1234        2       1.0
# 40            1180        2       2.0
# 42            2000        3       2.5
# 43            1519        5       2.0
# 46            1917        3       3.0
# 47            1095        3       1.0
# 48            3073        4       4.0
# 52            2650        4       4.0
# 53            3820        9       7.0
# 64            1605        3       2.0
# 67            2560        7       3.0
# 69             NaN        1       1.0
# 74            1885        3       2.0
# 77             722        1       1.0
# 78             668        2       1.0
# 79           31101        0       NaN
# 80            2411        4       2.0
# ..             ...      ...       ...
# 120            NaN      NaN       NaN
# 122            660        2       1.0
# 125           2772        6       4.0
# 128           2024        4       3.0
# 129           1557        3       2.0
# 132           2315        4       2.0
# 135           1154        2      2.25
# 140           1555        2       NaN
# 145           1651        4       2.0
# 148           3778        7       5.0
# 149           1193        3       2.0
# 154           1182        2       1.0
# 155            NaN      NaN       NaN
# 159           1544        3       1.0
# 165           2534        6       2.0
# 166           2834        6       2.0
# 169           2000        3       NaN
# 171           1137        2       1.0
# 173           1848        2       2.0
# 175           1666        4       3.0
# 176            NaN      NaN       NaN
# 177            NaN        0       NaN
# 180           1302        3       2.0
# 182           1569        3       1.0
# 188            631        0       1.0
# 191           1098        2       2.0
# 192           1848        3       3.0
# 193           1232        2       1.0
# 194            912        2       1.0
# 195           1011        2       1.0
#
# [70 rows x 17 columns]

# %%
# do any further data cleaning you need to yourself
# for example, dropping any rows with NaN values
la_df = la_df.dropna(axis=0, how='any')
la_df

# maybe write to CSV to store the data for usage later/before doing plots? so you don't have to rerun everything
# Out:
#            zpid                  address             city_state_zip latitude  \
# 0      20850860     4651 Castle Crest Dr       Los Angeles CA 90041  34.1344
# 3      20848463          4443 Verdugo Rd       Los Angeles CA 90065   34.132
# 5      20775277       520 S Lucerne Blvd       Los Angeles CA 90020  34.0646
# 6      20760983          638 Pheasant Dr       Los Angeles CA 90065  34.1042
# 11     62018650          2880 E Gage Ave   Huntington Park CA 90255  33.9804
# 12     20848238          1305 Romulus Dr          Glendale CA 91205  34.1347
# 13     20639008          4772 Academy St       Los Angeles CA 90032  34.0864
# 15     20750599        3529 La Clede Ave       Los Angeles CA 90039  34.1198
# 22     21030425       3160 California St   Huntington Park CA 90255  33.9708
# 32     20635402          1118 Calzona St       Los Angeles CA 90023  34.0203
# 33     21074186           6811 Rugby Ave   Huntington Park CA 90255  33.9778
# 37     20640073   4501 Richelieu Terrace       Los Angeles CA 90032  34.0767
# 40     20850137     5002 Sierra Villa Dr       Los Angeles CA 90041  34.1391
# 43     20572203            632 W 43rd St       Los Angeles CA 90037   34.005
# 46     20759873    1801 Sunny Heights Dr       Los Angeles CA 90065   34.107
# 47     20771595         6013 Meridian St       Los Angeles CA 90042  34.1204
# 48     20809501  5274 Los Caballeros Way       Los Angeles CA 90027  34.1099
# 52     20811910         3899 Amesbury Rd       Los Angeles CA 90027  34.1196
# 53     20790013        723 N Ardmore Ave       Los Angeles CA 90029  34.0843
# 64   2133329709             3849 3rd Ave       Los Angeles CA 90008  34.0165
