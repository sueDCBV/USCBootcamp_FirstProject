# %%
# ZILLOW DATA EXTRACTION WRITTEN BY SONIA YANG

# Dependencies
import requests
import urllib
import random
import math
import pandas as pd
import xml.etree.ElementTree as ET
import time
from config import zws_id, gkey # please use your own Zillow & Google API keys!
from urllib.request import urlopen

# %%
# FUNCTION to grab the exact address based on longitude and latitude
# modified from here https://gist.github.com/bradmontgomery/5397472
# their example didn't include an API key, but I added it otherwise you'd hit the rate limit easily

def reverse_geocode(latitude, longitude):
    # Did the geocoding request comes from a device with a
    # location sensor? Must be either true or false
    sensor = 'true'

    # Hit Google's reverse geocoder directly
    # NOTE: I *think* their terms state that you're supposed to
    # use google maps if you use their api for anything.
    base = "https://maps.googleapis.com/maps/api/geocode/json?"
    params = "latlng={lat},{lon}&sensor={sen}&key={key}".format(
        lat=latitude,
        lon=longitude,
        sen=sensor,
        key=gkey
    )
    url = "{base}{params}".format(base=base, params=params)
    #print(url)
    response = requests.get(url).json()
    address = response['results'][0]['formatted_address']
    return address

# %%
# FUNCTION to generate random lat & lng within a certain radius 
# modified from here: http://hadoopguru.blogspot.com/2014/12/python-generate-random-latitude-and.html
# changed to take in an empty initial dataframe and load in the data + return it
# this calls the reverse geocode function to grab the addresses of each randomly generated lat & lng

def generate_addresses(latitude, longitude, df):
    
    radius = 10000                         #Choose your own radius
    radiusInDegrees=radius/111300            
    r = radiusInDegrees

    counter = 0
    
    for i in range(1,200):                 #Choose number of Lat Long to be generated

        u = float(random.uniform(0.0,1.0))
        v = float(random.uniform(0.0,1.0))

        w = r * math.sqrt(u)
        t = 2 * math.pi * v
        x = w * math.cos(t) 
        y = w * math.sin(t)

        xLat  = x + latitude
        yLng = y + longitude

        df.set_value(counter, "latitude", xLat)
        df.set_value(counter, "longitude", yLng)
        
        #print(format(counter) + ": " + format(xLat) + ", " + format(yLng))
        address = reverse_geocode(xLat, yLng).split(',')
        citystatezip = address[1] + address[2]
        
        df.set_value(counter, "address", address[0])
        df.set_value(counter, "city_state_zip", citystatezip)
        
        # Add to counter
        counter = counter + 1
    
    return df

# %%
# FUNCTION to call Zillow API's GetSearchResults and will check to see if a house exists at that address
# message code will be written to dataframe
# zillow url format
# http://www.zillow.com/webservice/GetSearchResults.htm?zws-id=<ZWSID>&address=2114+Bigelow+Ave&citystatezip=Seattle%2C+WA
        
def get_message_codes(df):

    for index, row in df.iterrows():

        try:
            url = 'https://www.zillow.com/webservice/GetSearchResults.htm?zws-id='
            address = row['address']
            citystatezip =row['city_state_zip']


            query_url = url + zws_id + '&address=' + urllib.parse.quote(address) + '&citystatezip=' + urllib.parse.quote(citystatezip) 
            #print(query_url)

            root = ET.parse(urlopen(query_url)).getroot()

            for message in root.iter('message'):
                message_code = message[1].text

            print(format(index) + ": " + message_code)

            df.set_value(index, 'message_code', message_code)

            time.sleep(0.5) #necessary bc bombarding Zillow with API calls doesn't allow enough time to respond to each

        except:
            break

# %%
# FUNCTION to call Zillow's GetDeepSearchResults and look up Zestimate, bed, and bath
# http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=<ZWSID>&address=2114+Bigelow+Ave&citystatezip=Seattle%2C+WA
# there are some limitations such as multiple zestimates depending on when the house was sold/if it was sold multiple times
# the code to handle that would get too convoluted so I am just writing in the most recent (according to the API) values
# probably not what we would do in real life
# but a decision we made re: the scope of a classroom project on a short time constraint

def search_zillow(df):
    
    for index, row in df.iterrows():
        try:
            url = 'https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id='
            address = df['address'][index]
            citystatezip = df['city_state_zip'][index]


            query_url = url + zws_id + '&address=' + urllib.parse.quote(address) + '&citystatezip=' + urllib.parse.quote(citystatezip) 


            root = ET.parse(urlopen(query_url)).getroot()

            print("row " + format(index) + ": " + address + citystatezip)
            print(query_url)

            for zestimate in root.iter('zestimate'):
                zestimate_value = zestimate[0].text

                if zestimate_value is None:
                    print('not for sale')
                else:
                    print ('zestimate (value): ' + format(zestimate[0].text)) 
                    df.set_value(index, 'zestimate', zestimate_value)

            for bedroom in root.iter('bedrooms'):
                bedrooms = bedroom.text
                print("bedrooms: " + bedrooms)
                df.set_value(index, 'zillow_bedrooms', bedrooms)

            for bathroom in root.iter('bathrooms'):
                bathrooms = bathroom.text
                print("bathrooms: " + bathrooms + "\n")
                df.set_value(index, 'zillow_bathrooms', bathrooms)           
            
            print('\n')

            time.sleep(0.5) 


        except:
            break

# %% [markdown]
# <h2>HOW TO RUN THIS CODE</h2>
# <ol>
# <li>Initialize an empty dataframe with the fields as marked below</li>
# <li>Call the <strong>generate_addresses</strong> function passing in your empty dataframe</li>
# <li>Call the <strong>get_message_codes</strong> to update your dataframe with message codes indicating whether or not a valid property exists at each address. <strong>IMPORTANT:</strong> please register your own Zillow account/get your own key for this!! If we all keep using the same one we'll easily hit the rate limit </li>
# <li>Drop the rows in the dataframe for which a property does not exist at that address</li>
# <li>Call the <strong>search_zillow</strong> function to get the zestimate (aka price of the property), # of bedrooms, and # of bathrooms</li>
# <li>I did not include it in my code, but once you get a sample size of data that you are satisfied with for the city, maybe write it out to a CSV so you don't have to keep running this code/can use it later</li>
# </ol>
#
# feel free to comment out my print statements while the functions are running if you find them distracting

# %%
# HOW TO RUN ALL THE FUNCTIONS, USING LOS ANGELES AS AN EXAMPLE

# coordinates taken from the CitiesGeo_Output.csv
# we should manually run the following code on each individual city instead of nesting it in another loop
# while this may be hardcoded, it's better than waiting on one gigantic loop that takes forever

# STEP 1: INITALIZE THE DATAFRAME
# if we need any more fields, let me know
la_df = pd.DataFrame({"latitude":'',
                      "longitude":'',
                      "address":'',
                      "city_state_zip":'',
                      "message_code":'',
                      "zestimate":'',
                      "zillow_bedrooms":'',
                      "zillow_bathrooms":''}, index=[0])

# STEP 2: GENERATE RANDOM ADDRESSES IN THE DESIGNATED AREA
# pass in the coordinates for Los Angeles plus the empty dataframe
generate_addresses(34.0522342,-118.2436849, la_df)
# Out:
#                         address              city_state_zip latitude  \
# 0                3801 Sutro Ave        Los Angeles CA 90008  34.0177
# 1            739 Fremont Villas        Los Angeles CA 90042  34.0965
# 2              1907 Redcliff St        Los Angeles CA 90039  34.0943
# 3                1206 W 36th St        Los Angeles CA 90007  34.0227
# 4           2911-2919 Paola Ave        Los Angeles CA 90032  34.0806
# 192                3269 Zoe Ave    Huntington Park CA 90255  33.9791
# 193      Commonwealth Canyon Dr        Los Angeles CA 90027  34.1205
# 194             4569 Alumni Ave        Los Angeles CA 90041   34.126
# 195       5748-5770 Slauson Ave        Los Angeles CA 90058  33.9897
# 196         3390-3498 E 50th St             Vernon CA 90058  33.9982
# 197               913 E 53rd St        Los Angeles CA 90011  33.9943
# 198              930 Fraser Ave   East Los Angeles CA 90022  34.0205
#
#     longitude message_code zestimate zillow_bathrooms zillow_bedrooms
# 0    -118.324
# 1    -118.183          NaN       NaN              NaN             NaN
# 2     -118.27          NaN       NaN              NaN             NaN
# 3    -118.295          NaN       NaN              NaN             NaN
# 4    -118.181          NaN       NaN              NaN             NaN
# 5    -118.278          NaN       NaN              NaN             NaN
# 6    -118.237          NaN       NaN              NaN             NaN
# 7    -118.268          NaN       NaN              NaN             NaN
# 8    -118.284          NaN       NaN              NaN             NaN
# 9    -118.262          NaN       NaN              NaN             NaN
# 10   -118.272          NaN       NaN              NaN             NaN
# 11   -118.255          NaN       NaN              NaN             NaN
# 12   -118.288          NaN       NaN              NaN             NaN
# 13   -118.229          NaN       NaN              NaN             NaN
# 14   -118.208          NaN       NaN              NaN             NaN
# 15   -118.307          NaN       NaN              NaN             NaN
# 16   -118.202          NaN       NaN              NaN             NaN
# 17   -118.219          NaN       NaN              NaN             NaN
# 18   -118.166          NaN       NaN              NaN             NaN
# 19   -118.248          NaN       NaN              NaN             NaN
# 20   -118.302          NaN       NaN              NaN             NaN
# 21   -118.195          NaN       NaN              NaN             NaN
# 22   -118.246          NaN       NaN              NaN             NaN
# 23   -118.181          NaN       NaN              NaN             NaN
# 24   -118.326          NaN       NaN              NaN             NaN
# 25   -118.193          NaN       NaN              NaN             NaN
# 26   -118.293          NaN       NaN              NaN             NaN
# 27   -118.241          NaN       NaN              NaN             NaN
# 28   -118.217          NaN       NaN              NaN             NaN
# 29   -118.215          NaN       NaN              NaN             NaN
# ..        ...          ...       ...              ...             ...
# 169  -118.191          NaN       NaN              NaN             NaN
# 170  -118.253          NaN       NaN              NaN             NaN
# 171  -118.188          NaN       NaN              NaN             NaN
# 172  -118.245          NaN       NaN              NaN             NaN
# 173  -118.312          NaN       NaN              NaN             NaN
# 174  -118.197          NaN       NaN              NaN             NaN
# 175  -118.222          NaN       NaN              NaN             NaN
# 176  -118.265          NaN       NaN              NaN             NaN
# 177  -118.293          NaN       NaN              NaN             NaN
# 178  -118.267          NaN       NaN              NaN             NaN
# 179  -118.296          NaN       NaN              NaN             NaN
# 180   -118.26          NaN       NaN              NaN             NaN
# 181  -118.288          NaN       NaN              NaN             NaN
# 182  -118.243          NaN       NaN              NaN             NaN
# 183   -118.18          NaN       NaN              NaN             NaN
# 184  -118.273          NaN       NaN              NaN             NaN
# 185  -118.295          NaN       NaN              NaN             NaN
# 186  -118.206          NaN       NaN              NaN             NaN
# 187  -118.196          NaN       NaN              NaN             NaN
# 188  -118.294          NaN       NaN              NaN             NaN
# 189  -118.177          NaN       NaN              NaN             NaN
# 190  -118.223          NaN       NaN              NaN             NaN
# 120             415 E 69th St        Los Angeles CA 90003  33.9772  -118.267
# 121             3802 Tracy St        Los Angeles CA 90027  34.1057  -118.276
# 122   2610 Griffith Park Blvd        Los Angeles CA 90039  34.1053  -118.272
# 127            4212 Folsom St        Los Angeles CA 90063  34.0448  -118.175
# 129  1430 S New Hampshire Ave        Los Angeles CA 90006  34.0453  -118.292
# 130           7544 Verano Way        Walnut Park CA 90255  33.9709  -118.232
# 133        1401 N Hobart Blvd        Los Angeles CA 90027  34.0967  -118.306
# 135            4312 E 53rd St            Maywood CA 90270  33.9927  -118.189
# 136          3800 W Legion Ln        Los Angeles CA 90039   34.119  -118.268
# 139          2809 Randolph St    Huntington Park CA 90255  33.9853   -118.22
# 144           3584 Tacoma Ave        Los Angeles CA 90065  34.0981  -118.225
# 146        2911 S Hobart Blvd        Los Angeles CA 90018  34.0287  -118.308
# 147       5921 S San Pedro St        Los Angeles CA 90003  33.9868   -118.27
# 154   215 Commonwealth Avenue        Los Angeles CA 90004  34.0704  -118.286
# 155      206 W Chevy Chase Dr           Glendale CA 91204  34.1334  -118.257
# 160       1386 E Garfield Ave           Glendale CA 91205   34.137  -118.234
# 162           3800 Roxton Ave        Los Angeles CA 90008  34.0173  -118.321
# 166            1816 W 38th Pl        Los Angeles CA 90062  34.0162  -118.314
# 170       2123 Lake Shore Ave        Los Angeles CA 90039  34.0916  -118.253
# 175      1741 College View Pl        Los Angeles CA 90041  34.1268  -118.222
# 176     1858 W Silver Lake Dr        Los Angeles CA 90026  34.0943  -118.265
# 177            1546 W 22nd Pl        Los Angeles CA 90007  34.0354  -118.293
# 180           3700 Revere Ave        Los Angeles CA 90039  34.1212   -118.26
# 181    452 N Westmoreland Ave        Los Angeles CA 90004  34.0791  -118.288
# 185       544 N Heliotrope Dr        Los Angeles CA 90004  34.0804  -118.295
# 190            2501 Kerwin Pl        Los Angeles CA 90065  34.1365  -118.223
# 191          5319 Monterey Rd        Los Angeles CA 90042   34.099   -118.19
# 192              3269 Zoe Ave    Huntington Park CA 90255  33.9791  -118.208
#
#     message_code zestimate zillow_bathrooms zillow_bedrooms
# 0              0
# 1              0       NaN              NaN             NaN
# 2              0       NaN              NaN             NaN
# 3              0       NaN              NaN             NaN
# 7              0       NaN              NaN             NaN
# 9              0       NaN              NaN             NaN
# 15             0       NaN              NaN             NaN
# 16             0       NaN              NaN             NaN
# 17             0       NaN              NaN             NaN
# 18             0       NaN              NaN             NaN
# 24             0       NaN              NaN             NaN
# 29             0       NaN              NaN             NaN
# 31             0       NaN              NaN             NaN
# 33             0       NaN              NaN             NaN
# 34             0       NaN              NaN             NaN
# 37             0       NaN              NaN             NaN
# 41             0       NaN              NaN             NaN
# 44             0       NaN              NaN             NaN
# 45             0       NaN              NaN             NaN
# 47             0       NaN              NaN             NaN
# 49             0       NaN              NaN             NaN
# 53             0       NaN              NaN             NaN
# 58             0       NaN              NaN             NaN
# 59             0       NaN              NaN             NaN
# 60             0       NaN              NaN             NaN
# 62             0       NaN              NaN             NaN
# 63             0       NaN              NaN             NaN
# 67             0       NaN              NaN             NaN
# 69             0       NaN              NaN             NaN
# 72             0       NaN              NaN             NaN
# ..           ...       ...              ...             ...
# 114            0       NaN              NaN             NaN
# 117            0       NaN              NaN             NaN
# 120            0       NaN              NaN             NaN
# 121            0       NaN              NaN             NaN
# 122            0       NaN              NaN             NaN
# 127            0       NaN              NaN             NaN
# 129            0       NaN              NaN             NaN
# 130            0       NaN              NaN             NaN
# 133            0       NaN              NaN             NaN
# 135            0       NaN              NaN             NaN
# 136            0       NaN              NaN             NaN
# 139            0       NaN              NaN             NaN
# 144            0       NaN              NaN             NaN
# 146            0       NaN              NaN             NaN
# 147            0       NaN              NaN             NaN
# 154            0       NaN              NaN             NaN
# 155            0       NaN              NaN             NaN
# 160            0       NaN              NaN             NaN
# 162            0       NaN              NaN             NaN
# 166            0       NaN              NaN             NaN
# 170            0       NaN              NaN             NaN
# 175            0       NaN              NaN             NaN
# 176            0       NaN              NaN             NaN
# 177            0       NaN              NaN             NaN
# 180            0       NaN              NaN             NaN
# 181            0       NaN              NaN             NaN
# 185            0       NaN              NaN             NaN
# 190            0       NaN              NaN             NaN
# 191            0       NaN              NaN             NaN
# 192            0       NaN              NaN             NaN
#
# [78 rows x 8 columns]

# %%
# STEP 5: SEARCH ZILLOW AND GET ZESTIMATE, BEDROOMS, & BATHROOMS
# fill the dataframe with the data

search_zillow(la_df)
la_df
# Out:
# row 0: 3801 Sutro Ave Los Angeles CA 90008
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3801%20Sutro%20Ave&citystatezip=%20Los%20Angeles%20CA%2090008
# zestimate (value): 764746
# bedrooms: 2
# bathrooms: 2.0
#
#
#
# row 1: 739 Fremont Villas Los Angeles CA 90042
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=739%20Fremont%20Villas&citystatezip=%20Los%20Angeles%20CA%2090042
# zestimate (value): 534876
# bedrooms: 2
# bathrooms: 2.0
#
#
#
# row 2: 1907 Redcliff St Los Angeles CA 90039
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1907%20Redcliff%20St&citystatezip=%20Los%20Angeles%20CA%2090039
# not for sale
#
#
# row 3: 1206 W 36th St Los Angeles CA 90007
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1206%20W%2036th%20St&citystatezip=%20Los%20Angeles%20CA%2090007
# zestimate (value): 809670
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 7: 443 46th St Los Angeles CA 90011
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=443%2046th%20St&citystatezip=%20Los%20Angeles%20CA%2090011
# zestimate (value): 422864
# bedrooms: 4
# bathrooms: 1.0
#
#
#
# row 9: 715 E 78th St Los Angeles CA 90001
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=715%20E%2078th%20St&citystatezip=%20Los%20Angeles%20CA%2090001
# zestimate (value): 331920
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 15: 3027 W 12th Pl Los Angeles CA 90006
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3027%20W%2012th%20Pl&citystatezip=%20Los%20Angeles%20CA%2090006
# zestimate (value): 924100
# bedrooms: 5
# bathrooms: 3.0
#
#
#
# row 16: 3525 E 53rd St Maywood CA 90270
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3525%20E%2053rd%20St&citystatezip=%20Maywood%20CA%2090270
# zestimate (value): 432302
# bedrooms: 2
# bathrooms: 2.0
#
#
#
# row 17: 2312 Norwalk Ave Los Angeles CA 90041
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2312%20Norwalk%20Ave&citystatezip=%20Los%20Angeles%20CA%2090041
# zestimate (value): 960272
# bedrooms: 3
# bathrooms: 3.0
#
#
#
# row 18: 4620 Eugene St East Los Angeles CA 90022
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4620%20Eugene%20St&citystatezip=%20East%20Los%20Angeles%20CA%2090022
# zestimate (value): 482748
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 24: 3707 Montclair St Los Angeles CA 90018
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3707%20Montclair%20St&citystatezip=%20Los%20Angeles%20CA%2090018
#
#
# row 29: 4661 Palmero Dr Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4661%20Palmero%20Dr&citystatezip=%20Los%20Angeles%20CA%2090065
# zestimate (value): 1267659
# bedrooms: 4
# bathrooms: 4.0
#
#
#
# row 31: 2421 Las Colinas Ave Los Angeles CA 90041
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2421%20Las%20Colinas%20Ave&citystatezip=%20Los%20Angeles%20CA%2090041
# zestimate (value): 1136095
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 33: 1636 Pyrenees Dr Alhambra CA 91803
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1636%20Pyrenees%20Dr&citystatezip=%20Alhambra%20CA%2091803
# zestimate (value): 702466
# bedrooms: 2
# bathrooms: 2.0
#
#
#
# row 34: 3518 Stockbridge Ave Los Angeles CA 90032
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3518%20Stockbridge%20Ave&citystatezip=%20Los%20Angeles%20CA%2090032
# zestimate (value): 591396
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 37: 1803 W 36th Pl Los Angeles CA 90018
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1803%20W%2036th%20Pl&citystatezip=%20Los%20Angeles%20CA%2090018
# zestimate (value): 536577
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 41: 1467 Landa St Los Angeles CA 90031
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1467%20Landa%20St&citystatezip=%20Los%20Angeles%20CA%2090031
# zestimate (value): 744601
# bedrooms: 2
# bathrooms: 2.0
#
#
#
# row 44: 932 S Downey Rd Los Angeles CA 90023
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=932%20S%20Downey%20Rd&citystatezip=%20Los%20Angeles%20CA%2090023
# zestimate (value): 605162
# bedrooms: 6
# bathrooms: 3.0
#
#
#
# row 45: 729 Robinson St Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=729%20Robinson%20St&citystatezip=%20Los%20Angeles%20CA%2090026
# zestimate (value): 692886
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 47: 1702 W 55th St Los Angeles CA 90062
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1702%20W%2055th%20St&citystatezip=%20Los%20Angeles%20CA%2090062
# zestimate (value): 647688
# bedrooms: 8
# bathrooms: 4.0
#
#
#
# row 49: 1859 W Vernon Ave Los Angeles CA 90062
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1859%20W%20Vernon%20Ave&citystatezip=%20Los%20Angeles%20CA%2090062
# zestimate (value): 639918
# bedrooms: 4
# bathrooms: 3.0
#
#
#
# row 53: 4209 Glenmuir Ave Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4209%20Glenmuir%20Ave&citystatezip=%20Los%20Angeles%20CA%2090065
# not for sale
# zestimate (value): 635169
# bedrooms: 1
# bathrooms: 1.0
#
#
#
# row 58: 3550 W 6th St Los Angeles CA 90005
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3550%20W%206th%20St&citystatezip=%20Los%20Angeles%20CA%2090005
# zestimate (value): 809975
# not for sale
# not for sale
# bedrooms: 0
# bedrooms: 0
# bedrooms: 1
# bathrooms: 1.0
#
# bathrooms: 1.0
#
# bathrooms: 1.0
#
#
#
# row 59: 602 Park Row Dr Los Angeles CA 90012
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=602%20Park%20Row%20Dr&citystatezip=%20Los%20Angeles%20CA%2090012
# not for sale
# bedrooms: 0
#
#
# row 60: 1558 W 50th St Los Angeles CA 90062
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1558%20W%2050th%20St&citystatezip=%20Los%20Angeles%20CA%2090062
# zestimate (value): 467822
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 62: 4610 Hubbard St East Los Angeles CA 90022
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4610%20Hubbard%20St&citystatezip=%20East%20Los%20Angeles%20CA%2090022
# zestimate (value): 315951
# bedrooms: 1
# bathrooms: 1.0
#
#
#
# row 63: 1507 W Pico Blvd Los Angeles CA 90015
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1507%20W%20Pico%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090015
# zestimate (value): 548899
# bathrooms: 1.0
#
#
#
# row 67: 451 N Occidental Blvd Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=451%20N%20Occidental%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090026
# zestimate (value): 1172970
# bedrooms: 4
# bathrooms: 4.0
#
#
#
# row 69: 2411 Grand Ave Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2411%20Grand%20Ave&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 488324
# bedrooms: 4
# bathrooms: 2.0
#
#
#
# row 72: 823 Robinson St Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=823%20Robinson%20St&citystatezip=%20Los%20Angeles%20CA%2090026
# zestimate (value): 1255761
# bedrooms: 3
# bathrooms: 4.0
#
#
#
# row 74: 1346 1/2 Westerly Terrace Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1346%201/2%20Westerly%20Terrace&citystatezip=%20Los%20Angeles%20CA%2090026
# not for sale
# not for sale
# bedrooms: 0
# bedrooms: 0
#
#
# row 75: 1256 W 29th St Los Angeles CA 90007
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1256%20W%2029th%20St&citystatezip=%20Los%20Angeles%20CA%2090007
# not for sale
# not for sale
# bedrooms: 1
# bedrooms: 0
# bathrooms: 1.0
#
# bathrooms: 1.0
# row 76: 2458 Flower St Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2458%20Flower%20St&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 581355
# bedrooms: 4
# bathrooms: 4.0
#
#
#
# row 77: 2406 Tesla Terrace Los Angeles CA 90039
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2406%20Tesla%20Terrace&citystatezip=%20Los%20Angeles%20CA%2090039
# zestimate (value): 1882837
# bedrooms: 4
# bathrooms: 2.0
#
#
#
# row 79: 425S S Windsor Blvd Los Angeles CA 90020
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=425S%20S%20Windsor%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090020
# zestimate (value): 4454606
# bedrooms: 5
# bathrooms: 3.0
#
#
#
# row 80: 874 W 40th Pl Los Angeles CA 90037
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=874%20W%2040th%20Pl&citystatezip=%20Los%20Angeles%20CA%2090037
# zestimate (value): 1007343
# bedrooms: 7
# bathrooms: 5.0
#
#
#
# row 81: 3943 La Salle Ave Los Angeles CA 90062
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3943%20La%20Salle%20Ave&citystatezip=%20Los%20Angeles%20CA%2090062
# zestimate (value): 550661
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 82: 2800 Minto Ct Los Angeles CA 90032
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2800%20Minto%20Ct&citystatezip=%20Los%20Angeles%20CA%2090032
# zestimate (value): 579779
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 84: 5004 Patagonia Court Los Angeles CA 90004
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=5004%20Patagonia%20Court&citystatezip=%20Los%20Angeles%20CA%2090004
# zestimate (value): 1081829
# bedrooms: 3
# bathrooms: 3.0
#
#
#
# row 87: 4101 Parva Ave Los Angeles CA 90027
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4101%20Parva%20Ave&citystatezip=%20Los%20Angeles%20CA%2090027
# zestimate (value): 2619997
# bedrooms: 4
# bathrooms: 3.0
#
#
#
# row 91: 4225 2nd Ave Los Angeles CA 90008
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4225%202nd%20Ave&citystatezip=%20Los%20Angeles%20CA%2090008
# zestimate (value): 657433
# bedrooms: 4
# bathrooms: 2.0
#
#
#
# row 95: 1656 Lemoyne St Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1656%20Lemoyne%20St&citystatezip=%20Los%20Angeles%20CA%2090026
# zestimate (value): 854895
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 99: 1256 W Gage Ave Los Angeles CA 90044
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1256%20W%20Gage%20Ave&citystatezip=%20Los%20Angeles%20CA%2090044
# zestimate (value): 425623
# bedrooms: 0
#
#
# row 103: 1143 E 62nd St Los Angeles CA 90001
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1143%20E%2062nd%20St&citystatezip=%20Los%20Angeles%20CA%2090001
# zestimate (value): 421392
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 104: 6047 Templeton St Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=6047%20Templeton%20St&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 471533
# bedrooms: 3
# bathrooms: 3.0
#
#
#
# row 108: 434s S Rossmore Ave Los Angeles CA 90020
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=434s%20S%20Rossmore%20Ave&citystatezip=%20Los%20Angeles%20CA%2090020
# zestimate (value): 6073545
# bedrooms: 3
# bathrooms: 6.0
#
#
#
# row 110: 4664 W 3rd St Los Angeles CA 90020
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4664%20W%203rd%20St&citystatezip=%20Los%20Angeles%20CA%2090020
# zestimate (value): 932768
#
#
# row 113: 5960 Echo St Los Angeles CA 90042
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=5960%20Echo%20St&citystatezip=%20Los%20Angeles%20CA%2090042
# zestimate (value): 610066
#
#
# row 114: 1463 Glendale Blvd Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1463%20Glendale%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090026
# not for sale
# bedrooms: 3
# bathrooms: 1.0
#
#
#
# row 117: 130 Monterey Rd South Pasadena CA 91030
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=130%20Monterey%20Rd&citystatezip=%20South%20Pasadena%20CA%2091030
# zestimate (value): 613690
# zestimate (value): 615111
# zestimate (value): 555889
# zestimate (value): 615917
# zestimate (value): 606786
# zestimate (value): 616559
# zestimate (value): 539321
# zestimate (value): 617647
# zestimate (value): 607297
# zestimate (value): 613592
# zestimate (value): 629401
# zestimate (value): 755017
# zestimate (value): 616604
# zestimate (value): 613706
# zestimate (value): 610125
# zestimate (value): 612016
# zestimate (value): 629318
# zestimate (value): 598271
# zestimate (value): 613694
# zestimate (value): 621522
# zestimate (value): 607056
# zestimate (value): 558362
# zestimate (value): 618608
# zestimate (value): 620614
# zestimate (value): 612128
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 1
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bedrooms: 2
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 1.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 1.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
# bathrooms: 2.0
#
#
#
# row 120: 415 E 69th St Los Angeles CA 90003
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=415%20E%2069th%20St&citystatezip=%20Los%20Angeles%20CA%2090003
# zestimate (value): 359339
# bedrooms: 3
# bathrooms: 1.0
#
#
#
# row 121: 3802 Tracy St Los Angeles CA 90027
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3802%20Tracy%20St&citystatezip=%20Los%20Angeles%20CA%2090027
# zestimate (value): 1726081
# bedrooms: 6
# bathrooms: 4.0
#
#
#
# row 122: 2610 Griffith Park Blvd Los Angeles CA 90039
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2610%20Griffith%20Park%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090039
# zestimate (value): 1366356
# bedrooms: 4
# bathrooms: 2.0
#
#
#
# row 127: 4212 Folsom St Los Angeles CA 90063
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4212%20Folsom%20St&citystatezip=%20Los%20Angeles%20CA%2090063
# zestimate (value): 464336
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 129: 1430 S New Hampshire Ave Los Angeles CA 90006
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1430%20S%20New%20Hampshire%20Ave&citystatezip=%20Los%20Angeles%20CA%2090006
# zestimate (value): 583718
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 130: 7544 Verano Way Walnut Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=7544%20Verano%20Way&citystatezip=%20Walnut%20Park%20CA%2090255
# zestimate (value): 344244
# bedrooms: 3
# bathrooms: 3.0
#
#
#
# row 133: 1401 N Hobart Blvd Los Angeles CA 90027
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1401%20N%20Hobart%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090027
# zestimate (value): 1959720
# bedrooms: 4
# bathrooms: 4.0
#
#
#
# row 135: 4312 E 53rd St Maywood CA 90270
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=4312%20E%2053rd%20St&citystatezip=%20Maywood%20CA%2090270
# zestimate (value): 570802
# bedrooms: 5
# bathrooms: 3.0
#
#
#
# row 136: 3800 W Legion Ln Los Angeles CA 90039
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3800%20W%20Legion%20Ln&citystatezip=%20Los%20Angeles%20CA%2090039
# zestimate (value): 968204
# bedrooms: 0
# row 139: 2809 Randolph St Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2809%20Randolph%20St&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 411617
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 144: 3584 Tacoma Ave Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3584%20Tacoma%20Ave&citystatezip=%20Los%20Angeles%20CA%2090065
# not for sale
#
#
# row 146: 2911 S Hobart Blvd Los Angeles CA 90018
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2911%20S%20Hobart%20Blvd&citystatezip=%20Los%20Angeles%20CA%2090018
# zestimate (value): 606691
# bedrooms: 3
# bathrooms: 1.5
#
#
#
# row 147: 5921 S San Pedro St Los Angeles CA 90003
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=5921%20S%20San%20Pedro%20St&citystatezip=%20Los%20Angeles%20CA%2090003
# zestimate (value): 347828
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 154: 215 Commonwealth Avenue Los Angeles CA 90004
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=215%20Commonwealth%20Avenue&citystatezip=%20Los%20Angeles%20CA%2090004
# zestimate (value): 1373509
# bedrooms: 6
# bathrooms: 6.0
#
#
#
# row 155: 206 W Chevy Chase Dr Glendale CA 91204
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=206%20W%20Chevy%20Chase%20Dr&citystatezip=%20Glendale%20CA%2091204
# zestimate (value): 989732
# bedrooms: 4
# bathrooms: 3.0
#
#
#
# row 160: 1386 E Garfield Ave Glendale CA 91205
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1386%20E%20Garfield%20Ave&citystatezip=%20Glendale%20CA%2091205
# zestimate (value): 874377
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 162: 3800 Roxton Ave Los Angeles CA 90008
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3800%20Roxton%20Ave&citystatezip=%20Los%20Angeles%20CA%2090008
# zestimate (value): 666903
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 166: 1816 W 38th Pl Los Angeles CA 90062
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1816%20W%2038th%20Pl&citystatezip=%20Los%20Angeles%20CA%2090062
# zestimate (value): 556501
# bedrooms: 3
# bathrooms: 1.0
#
#
#
# row 170: 2123 Lake Shore Ave Los Angeles CA 90039
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2123%20Lake%20Shore%20Ave&citystatezip=%20Los%20Angeles%20CA%2090039
# zestimate (value): 1446115
# bedrooms: 6
# bathrooms: 2.0
#
#
#
# row 175: 1741 College View Pl Los Angeles CA 90041
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1741%20College%20View%20Pl&citystatezip=%20Los%20Angeles%20CA%2090041
# zestimate (value): 944177
# bedrooms: 4
# bathrooms: 3.0
#
#
#
# row 176: 1858 W Silver Lake Dr Los Angeles CA 90026
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1858%20W%20Silver%20Lake%20Dr&citystatezip=%20Los%20Angeles%20CA%2090026
# zestimate (value): 1076518
# bedrooms: 2
# bathrooms: 2.0
#
#
#
# row 177: 1546 W 22nd Pl Los Angeles CA 90007
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=1546%20W%2022nd%20Pl&citystatezip=%20Los%20Angeles%20CA%2090007
# zestimate (value): 485086
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 180: 3700 Revere Ave Los Angeles CA 90039
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3700%20Revere%20Ave&citystatezip=%20Los%20Angeles%20CA%2090039
# zestimate (value): 816570
# bedrooms: 2
# bathrooms: 1.0
#
#
#
# row 181: 452 N Westmoreland Ave Los Angeles CA 90004
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=452%20N%20Westmoreland%20Ave&citystatezip=%20Los%20Angeles%20CA%2090004
# zestimate (value): 911081
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 185: 544 N Heliotrope Dr Los Angeles CA 90004
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=544%20N%20Heliotrope%20Dr&citystatezip=%20Los%20Angeles%20CA%2090004
# zestimate (value): 753644
# not for sale
# bedrooms: 0
# bedrooms: 0
# bathrooms: 1.0
#
# bathrooms: 1.0
#
#
#
# row 190: 2501 Kerwin Pl Los Angeles CA 90065
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=2501%20Kerwin%20Pl&citystatezip=%20Los%20Angeles%20CA%2090065
# zestimate (value): 1042469
# bedrooms: 3
# bathrooms: 2.0
#
#
#
# row 191: 5319 Monterey Rd Los Angeles CA 90042
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=5319%20Monterey%20Rd&citystatezip=%20Los%20Angeles%20CA%2090042
# zestimate (value): 712438
# bedrooms: 3
# bathrooms: 1.0
#
#
#
# row 192: 3269 Zoe Ave Huntington Park CA 90255
# https://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz18op3r67qq3_ahuyo&address=3269%20Zoe%20Ave&citystatezip=%20Huntington%20Park%20CA%2090255
# zestimate (value): 332919
# bedrooms: 2
# bathrooms: 1.0
#                       address              city_state_zip latitude longitude  \
# 0              3801 Sutro Ave        Los Angeles CA 90008  34.0177  -118.324
# 1          739 Fremont Villas        Los Angeles CA 90042  34.0965  -118.183
# 2            1907 Redcliff St        Los Angeles CA 90039  34.0943   -118.27
# 3              1206 W 36th St        Los Angeles CA 90007  34.0227  -118.295
# 7                 443 46th St        Los Angeles CA 90011  34.0018  -118.268
# 9               715 E 78th St        Los Angeles CA 90001  33.9686  -118.262
# 15             3027 W 12th Pl        Los Angeles CA 90006  34.0486  -118.307
# 16             3525 E 53rd St            Maywood CA 90270  33.9948  -118.202
# 17           2312 Norwalk Ave        Los Angeles CA 90041  34.1328  -118.219
# 175      1741 College View Pl        Los Angeles CA 90041  34.1268  -118.222
# 176     1858 W Silver Lake Dr        Los Angeles CA 90026  34.0943  -118.265
# 177            1546 W 22nd Pl        Los Angeles CA 90007  34.0354  -118.293
# 180           3700 Revere Ave        Los Angeles CA 90039  34.1212   -118.26
# 181    452 N Westmoreland Ave        Los Angeles CA 90004  34.0791  -118.288
# 185       544 N Heliotrope Dr        Los Angeles CA 90004  34.0804  -118.295
# 190            2501 Kerwin Pl        Los Angeles CA 90065  34.1365  -118.223
# 191          5319 Monterey Rd        Los Angeles CA 90042   34.099   -118.19
# 192              3269 Zoe Ave    Huntington Park CA 90255  33.9791  -118.208
#
#     message_code zestimate zillow_bathrooms zillow_bedrooms
# 0              0    764746              2.0               2
# 1              0    534876              2.0               2
# 2              0       NaN              NaN             NaN
# 3              0    809670              2.0               3
# 7              0    422864              1.0               4
# 9              0    331920              1.0               2
# 15             0    924100              3.0               5
# 16             0    432302              2.0               2
# 17             0    960272              3.0               3
# 18             0    482748              2.0               3
# 24             0       NaN              NaN             NaN
# 29             0   1267659              4.0               4
# 31             0   1136095              2.0               3
# 33             0    702466              2.0               2
# 34             0    591396              1.0               2
# 37             0    536577              2.0               3
# 41             0    744601              2.0               2
# 44             0    605162              3.0               6
# 45             0    692886              1.0               2
# 47             0    647688              4.0               8
# 49             0    639918              3.0               4
# 53             0    635169              1.0               1
# 58             0    809975              1.0               1
# 59             0       NaN              NaN               0
# 60             0    467822              1.0               2
# 62             0    315951              1.0               1
# 63             0    548899              1.0             NaN
# 67             0   1172970              4.0               4
# 69             0    488324              2.0               4
# 72             0   1255761              4.0               3
# ..           ...       ...              ...             ...
# 114            0       NaN              1.0               3
# 117            0    612128              2.0               2
# 120            0    359339              1.0               3
# 121            0   1726081              4.0               6
# 122            0   1366356              2.0               4
# 127            0    464336              2.0               3
# 129            0    583718              2.0               3
# 130            0    344244              3.0               3
# 133            0   1959720              4.0               4
# 135            0    570802              3.0               5
# 136            0    968204              NaN               0
# 139            0    411617              1.0               2
# 144            0       NaN              NaN             NaN
# 146            0    606691              1.5               3
# 147            0    347828              1.0               2
# 154            0   1373509              6.0               6
# 155            0    989732              3.0               4
# 160            0    874377              2.0               3
# 162            0    666903              1.0               2
# 166            0    556501              1.0               3
# 170            0   1446115              2.0               6
# 175            0    944177              3.0               4
# 176            0   1076518              2.0               2
# 177            0    485086              1.0               2
# 180            0    816570              1.0               2
# 181            0    911081              2.0               3
# 185            0    753644              1.0               0
# 190            0   1042469              2.0               3
# 191            0    712438              1.0               3
# 192            0    332919              1.0               2
#
# [78 rows x 8 columns]

# %%
# do any further data cleaning you need to yourself
# for example, dropping any rows with NaN values
la_df = la_df.dropna(axis=0, how='any')
la_df

# maybe write to CSV to store the data for usage later/before doing plots? so you don't have to rerun everything
# Out:
#                       address              city_state_zip latitude longitude  \
# 0              3801 Sutro Ave        Los Angeles CA 90008  34.0177  -118.324
# 1          739 Fremont Villas        Los Angeles CA 90042  34.0965  -118.183
# 154   215 Commonwealth Avenue        Los Angeles CA 90004  34.0704  -118.286
# 155      206 W Chevy Chase Dr           Glendale CA 91204  34.1334  -118.257
# 160       1386 E Garfield Ave           Glendale CA 91205   34.137  -118.234
# 162           3800 Roxton Ave        Los Angeles CA 90008  34.0173  -118.321
# 166            1816 W 38th Pl        Los Angeles CA 90062  34.0162  -118.314
# 170       2123 Lake Shore Ave        Los Angeles CA 90039  34.0916  -118.253
# 175      1741 College View Pl        Los Angeles CA 90041  34.1268  -118.222
# 176     1858 W Silver Lake Dr        Los Angeles CA 90026  34.0943  -118.265
# 177            1546 W 22nd Pl        Los Angeles CA 90007  34.0354  -118.293
# 180           3700 Revere Ave        Los Angeles CA 90039  34.1212   -118.26
# 181    452 N Westmoreland Ave        Los Angeles CA 90004  34.0791  -118.288
# 185       544 N Heliotrope Dr        Los Angeles CA 90004  34.0804  -118.295
# 190            2501 Kerwin Pl        Los Angeles CA 90065  34.1365  -118.223
# 191          5319 Monterey Rd        Los Angeles CA 90042   34.099   -118.19
# 192              3269 Zoe Ave    Huntington Park CA 90255  33.9791  -118.208
#
#     message_code zestimate zillow_bathrooms zillow_bedrooms
# 0              0    764746              2.0               2
# 1              0    534876              2.0               2
# 3              0    809670              2.0               3
# 7              0    422864              1.0               4
# 9              0    331920              1.0               2
# 15             0    924100              3.0               5
# 16             0    432302              2.0               2
# 17             0    960272              3.0               3
# 18             0    482748              2.0               3
# 29             0   1267659              4.0               4
# 31             0   1136095              2.0               3
# 33             0    702466              2.0               2
# 34             0    591396              1.0               2
# 37             0    536577              2.0               3
# 41             0    744601              2.0               2
# 44             0    605162              3.0               6
# 45             0    692886              1.0               2
# 47             0    647688              4.0               8
# 49             0    639918              3.0               4
# 53             0    635169              1.0               1
# 58             0    809975              1.0               1
# 60             0    467822              1.0               2
# 62             0    315951              1.0               1
# 67             0   1172970              4.0               4
# 69             0    488324              2.0               4
# 72             0   1255761              4.0               3
# 76             0    581355              4.0               4
# 77             0   1882837              2.0               4
# 79             0   4454606              3.0               5
# 80             0   1007343              5.0               7
# ..           ...       ...              ...             ...
# 103            0    421392              2.0               3
# 104            0    471533              3.0               3
# 108            0   6073545              6.0               3
# 117            0    612128              2.0               2
# 120            0    359339              1.0               3
# 121            0   1726081              4.0               6
# 122            0   1366356              2.0               4
# 127            0    464336              2.0               3
# 129            0    583718              2.0               3
# 130            0    344244              3.0               3
# 133            0   1959720              4.0               4
# 135            0    570802              3.0               5
# 139            0    411617              1.0               2
# 146            0    606691              1.5               3
# 147            0    347828              1.0               2
# 154            0   1373509              6.0               6
# 155            0    989732              3.0               4
# 160            0    874377              2.0               3
# 162            0    666903              1.0               2
# 166            0    556501              1.0               3
# 170            0   1446115              2.0               6
# 175            0    944177              3.0               4
# 176            0   1076518              2.0               2
# 177            0    485086              1.0               2
# 180            0    816570              1.0               2
# 181            0    911081              2.0               3
# 185            0    753644              1.0               0
# 190            0   1042469              2.0               3
# 191            0    712438              1.0               3
# 192            0    332919              1.0               2
#
# [66 rows x 8 columns]
