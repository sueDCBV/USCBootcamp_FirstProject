# %% [markdown]
# ## Getting Crime Rate per City

# %% [markdown]
# ### Import crime dataset, this dataset is from Los Angeles City. org, we retrieved from this link:
# https://catalog.data.gov/dataset/crime-data-from-2010-to-present

# %%
##Import Crime Data 
import pandas as pd 
crime_data=pd.read_csv('../Raw_Data/7.2017_crime_data.csv')

# %% [markdown]
# ### Getting only needed columns from the dataset

# %%
#Pull associated Crime Code and Location
crime_data2=crime_data[['Location ','Crime Code']]
#Drop any NaN location
crime_data2 =crime_data2.dropna(axis=0, how='any')
crime_data2.head()
# Out:
#               Location   Crime Code
# 2  (34.0886, -118.2979)         510
# 3  (34.0512, -118.2787)         510
# 4  (34.0328, -118.2915)         510
# 5  (34.0676, -118.2202)         510
# 6  (33.7347, -118.2842)         510

# %%
#Need to change data type in order to strip out Lat and Lng
crime_data2['Location ']=crime_data2['Location '].astype('str')
# Split Lat and Lng
df = crime_data2['Location '].apply(lambda x: pd.Series(x.split(',')))
#create new columns to store Lat and Lng
df.columns=['lat','lng']
df

# %%
crime_data3=pd.concat([df,crime_data[['Crime Code']]],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-386e9a9a9ef1> in <module>()
# ----> 1 crime_data3=pd.concat([df,crime_data[['Crime Code']]],axis=1)
#
# NameError: name 'df' is not defined

# %%
crime_data_copy=crime_data3[:]

# %%
crime_data3=crime_data3[crime_data3.lng.str.contains("NaN") == False]

# %%
crime_data3['lat'] = crime_data3['lat'].map(lambda x: str(x)[1:])

# %%
crime_data3['lng'] = crime_data3['lng'].map(lambda x: str(x)[:-1])

# %%
import requests

gkey="AIzaSyBC0KeGBlUK4nn6b4nGdMUq-Dfuqq9ICbU"
def reverse_geocode(latitude, longitude):
    # Did the geocoding request comes from a device with a
    # location sensor? Must be either true or false
    sensor = 'true'

    # Hit Google's reverse geocoder directly
    # NOTE: I *think* their terms state that you're supposed to
    # use google maps if you use their api for anything.
    base = "https://maps.googleapis.com/maps/api/geocode/json?"
    params = "latlng={lat},{lon}&sensor={sen}&key={key}".format(
        lat=latitude,
        lon=longitude,
        sen=sensor,
        key=gkey
    )
    url = "{base}{params}".format(base=base, params=params)
    #print(url)
    response = requests.get(url).json()
    #print(response)
    address = response['results'][0]['formatted_address']
    return address

# %%
crime_data3=crime_data3.reset_index()
lat=crime_data3['lat']
lng=crime_data3['lng']
code=crime_data3['Crime Code']

# %%
##Write a loop to call geocode fuction for each lat lng in the crime_data3 
list_add=[]
for j in range(len(lat)):
    dic_add={}
    dic_add['lat']=lat[j]
    dic_add['lng']=lng[j]
    dic_add['code']=code[j]
    dic_add['add']=reverse_geocode(lat[j], lng[j])
    list_add.append(dic_add)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-178-5545f43a2fc6> in <module>()
#       5     dic_add['lng']=lng[j]
#       6     dic_add['code']=code[j]
# ----> 7     dic_add['add']=reverse_geocode(lat[j], lng[j])
#       8     list_add.append(dic_add)
#
# <ipython-input-173-f5311efeeaa9> in reverse_geocode(latitude, longitude)
#      21     response = requests.get(url).json()
#      22     #print(response)
# ---> 23     address = response['results'][0]['formatted_address']
#      24     return address
#
# IndexError: list index out of range

# %%
list_address=pd.DataFrame(list_add)
list_address
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
list_address['add'].apply(lambda x: pd.Series(x.split(',')))
# Out:
#                                0                   1          2     3
# 0      1003 1/2 N Alexandria Ave         Los Angeles   CA 90029   USA
# 1       1925-1999 W Olympic Blvd         Los Angeles   CA 90006   USA
# 2             1375a W Adams Blvd         Los Angeles   CA 90007   USA
# 3                1843 Darwin Ave         Los Angeles   CA 90031   USA
# 4                  332 W 11th St           San Pedro   CA 90731   USA
# 5              7099 Beverly Blvd         Los Angeles   CA 90036   USA
# 6                 260 S Broadway         Los Angeles   CA 90012   USA
# 7               231-299 E 3rd St         Los Angeles   CA 90013   USA
# 8       3043-3099 E Olympic Blvd         Los Angeles   CA 90023   USA
# 9              612 Echo Park Ave         Los Angeles   CA 90026   USA
# 10           162-202 Belmont Ave         Los Angeles   CA 90026   USA
# 11          1376-1398 Camulos St         Los Angeles   CA 90023   USA
# 12            755 S Westlake Ave         Los Angeles   CA 90057   USA
# 13                  229 W Ave 26         Los Angeles   CA 90031   USA
# 14             556-598 W 33rd St         Los Angeles   CA 90007   USA
# 15         3021 Lincoln Park Ave         Los Angeles   CA 90031   USA
# 16                  101 W 8th St         Los Angeles   CA 90014   USA
# 17             1300 Esperanza St         Los Angeles   CA 90023   USA
# 18         2601-2699 Artesian Pl         Los Angeles   CA 90031   USA
# 19         1000-1038 S Fresno St         Los Angeles   CA 90023   USA
# 20          3712-3728 Beswick St         Los Angeles   CA 90023   USA
# 21              333-399 W Opp St          Wilmington   CA 90744   USA
# 22              15280 De Pauw St   Pacific Palisades   CA 90272   USA
# 23           1190-1198 W 24th St           San Pedro   CA 90731   USA
# 24          101-199 S Benton Way         Los Angeles   CA 90057   USA
# 25                2241 W 15th St         Los Angeles   CA 90006   USA
# 26   14425-14429 W Magnolia Blvd        Sherman Oaks   CA 91423   USA
# 27            1111 L.A. Live Way         Los Angeles   CA 90015   USA
# 28            171-187 Arcadia St         Los Angeles   CA 90012   USA
# 29               427-499 Boyd St         Los Angeles   CA 90013   USA
# ..                           ...                 ...        ...   ...
# 91          701-799 Traction Ave         Los Angeles   CA 90013   USA
# 92              600-672 W 8th St         Los Angeles   CA 90014   USA
# 93              600-672 W 8th St         Los Angeles   CA 90014   USA
# 94              600-672 W 8th St         Los Angeles   CA 90014   USA
# 95              363-403 E 5th St         Los Angeles   CA 90013   USA
# 96                 125 E 11th St         Los Angeles   CA 90015   USA
# 97                  303 E 5th St         Los Angeles   CA 90013   USA
# 98           650-698 S Grand Ave         Los Angeles   CA 90017   USA
# 99                 698 S Hope St         Los Angeles   CA 90017   USA
# 100                  716 Yale St         Los Angeles   CA 90012   USA
# 101             363-403 E 5th St         Los Angeles   CA 90013   USA
# 102       491-499 W Olympic Blvd         Los Angeles   CA 90015   USA
# 103             768-798 W 9th St         Los Angeles   CA 90017   USA
# 104                529 Maple Ave         Los Angeles   CA 90013   USA
# 105             201-221 E 6th St         Los Angeles   CA 90014   USA
# 106                698 S Hope St         Los Angeles   CA 90017   USA
# 107             768-798 W 9th St         Los Angeles   CA 90017   USA
# 108            530-598 S Hope St         Los Angeles   CA 90071   USA
# 109                698 S Hope St         Los Angeles   CA 90017   USA
# 110       558-598 W Olympic Blvd         Los Angeles   CA 90015   USA
# 111             779-799 E 4th St         Los Angeles   CA 90013   USA
# 112           501 S San Pedro St         Los Angeles   CA 90013   USA
# 113       491-499 W Olympic Blvd         Los Angeles   CA 90015   USA
# 114                 611 E 5th St         Los Angeles   CA 90013   USA
# 115           888 W Olympic Blvd         Los Angeles   CA 90015   USA
# 116          801-899 N Vignes St         Los Angeles   CA 90012   USA
# 117                 335 E 1st St         Los Angeles   CA 90012   USA
# 118             600-612 W 5th St         Los Angeles   CA 90071   USA
# 119                698 S Hope St         Los Angeles   CA 90017   USA
# 120             814 Francisco St         Los Angeles   CA 90017   USA
#
# [121 rows x 4 columns]

# %%
address
# Out:
# 0         34.0886
# 1         34.0512
# 2         34.0328
# 3         34.0676
# 4         33.7347
# 5         34.0762
# 6          34.051
# 7          34.048
# 8          34.021
# 9         34.0699
# 10        34.0644
# 11        34.0225
# 12        34.0544
# 13        34.0797
# 14         34.023
# 15        34.0812
# 16        34.0428
# 17        34.0188
# 18        34.0806
# 19        34.0268
# 20        34.0203
# 21        33.7827
# 22        34.0385
# 23        33.7225
# 24        34.0697
# 25        34.0457
# 26        34.1649
# 27        34.0451
# 28        34.0565
# 29         34.046
#            ...
# 228917    33.9383
# 228918    33.9383
# 228919    33.9262
# 228920    34.2959
# 228921    34.2265
# 228922     34.316
# 228923    34.3155
# 228924    34.3155
# 228925    34.2319
# 228926    34.2978
# 228927     34.274
# 228928     34.304
# 228929     34.069
# 228930    34.0617
# 228931    34.0382
# 228932    34.0618
# 228933    34.0598
# 228934    34.0597
# 228935    34.0652
# 228936    34.0436
# 228937    34.0636
# 228938    34.0817
# 228939    34.1865
# 228940     34.212
# 228941     34.206
# 228942     34.172
# 228943    34.2138
# 228944    34.2246
# 228945    34.2106
# 228946    34.2213
# Name: lat, Length: 228947, dtype: object
