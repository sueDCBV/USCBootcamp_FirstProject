# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import seaborn as sns

# %%
# Ranking is available through website: http://school-ratings.com/counties/Los_Angeles.html no API calls needed
school_csr_df = pd.read_csv("../Raw_Data/4.LA_cities_school_ranking.csv",encoding = "ISO-8859-1")
#zipcodes_df = zipcodes_df.rename(columns={"zip": "Zipcode","County":"City"})

school_csr_df.head()
# Out:
#        CITY                         SCHOOL_RAW                  SCHOOL  CSR
# 0  Alhambra          Alhambra High CSR rank: 8          Alhambra High     8
# 1  Alhambra           Century High CSR rank: 3           Century High     3
# 2  Alhambra  Emery Park Elementary CSR rank: 7  Emery Park Elementary     7
# 3  Alhambra     Fremont Elementary CSR rank: 5     Fremont Elementary     5
# 4  Alhambra    Garfield Elementary CSR rank: 8    Garfield Elementary     8

# %%
#Filter only selected cities for analysis
selected_cities=['Alhambra','Burbank','Inglewood','Glendale','Long Beach','Los Angeles','Palmdale','Pasadena','Santa Clarita','Torrance']
school_csr_df=school_csr_df[school_csr_df['CITY'].isin(selected_cities)]
school_csr_df
# Out:
#          CITY                                     SCHOOL_RAW  \
# 0    Alhambra                      Alhambra High CSR rank: 8
# 1    Alhambra                       Century High CSR rank: 3
# 2    Alhambra              Emery Park Elementary CSR rank: 7
# 3    Alhambra                 Fremont Elementary CSR rank: 5
# 4    Alhambra                Garfield Elementary CSR rank: 8
# 5    Alhambra                 Granada Elementary CSR rank: 5
# 6    Alhambra      Alternative Independence High CSR rank: 3
# 7    Alhambra              Marguerita Elementary CSR rank: 7
# 8    Alhambra                  Mark Keppel High CSR rank: 10
# 9    Alhambra          Martha Baldwin Elementary CSR rank: 9
# 10   Alhambra                    Park Elementary CSR rank: 8
# 11   Alhambra                  Ramona Elementary CSR rank: 8
# 12   Alhambra        William Northrup Elementary CSR rank: 7
# 13    Burbank              Bret Harte Elementary CSR rank: 7
# 14    Burbank                       Burbank High CSR rank: 8
# 15    Burbank                     Burroughs High CSR rank: 9
# 16    Burbank          David Starr Jordan Middle CSR rank: 7
# 17    Burbank       George Washington Elementary CSR rank: 8
# 18    Burbank          Joaquin Miller Elementary CSR rank: 9
# 19    Burbank                   John Muir Middle CSR rank: 8
# 20    Burbank              Luther Burbank Middle CSR rank: 7
# 21    Burbank         Continuation Monterey High CSR rank: 2
# 22    Burbank  Options for Youth-Burbank Charter CSR rank: 4
# 23    Burbank             Providencia Elementary CSR rank: 7
# 24    Burbank         R. L. Stevenson Elementary CSR rank: 9
# 25    Burbank           Ralph Emerson Elementary CSR rank: 8
# 26    Burbank      Theodore Roosevelt Elementary CSR rank: 9
# 27    Burbank           Thomas Edison Elementary CSR rank: 9
# 28    Burbank        Thomas Jefferson Elementary CSR rank: 9
# 29    Burbank             Walt Disney Elementary CSR rank: 7
# ..        ...                                            ...
# 941  Torrance                   Anza Elementary CSR rank: 10
# 942  Torrance               Arlington Elementary CSR rank: 9
# 943  Torrance               Bert M. Lynn Middle CSR rank: 10
# 944  Torrance                 Calle Mayor Middle CSR rank: 9
# 945  Torrance                     Casimir Middle CSR rank: 8
# 946  Torrance                  Edison Elementary CSR rank: 8
# 947  Torrance       Edward J. Richardson Middle CSR rank: 10
# 948  Torrance             Evelyn Carr Elementary CSR rank: 7
# 949  Torrance                    Fern Elementary CSR rank: 8
# 950  Torrance                 Hickory Elementary CSR rank: 9
# 951  Torrance             Howard Wood Elementary CSR rank: 8
# 952  Torrance                  J. H. Hull Middle CSR rank: 6
# 953  Torrance                   Jefferson Middle CSR rank: 9
# 954  Torrance              John Adams Elementary CSR rank: 8
# 955  Torrance           Joseph Arnold Elementary CSR rank: 9
# 956  Torrance                 Lincoln Elementary CSR rank: 8
# 957  Torrance                     Madrona Middle CSR rank: 9
# 958  Torrance                         North High CSR rank: 9
# 959  Torrance             Philip Magruder Middle CSR rank: 8
# 960  Torrance                Riviera Elementary CSR rank: 10
# 961  Torrance                Seaside Elementary CSR rank: 10
# 962  Torrance  Kurt T. Shery High (Continuation) CSR rank: 3
# 963  Torrance                        South High CSR rank: 10
# 964  Torrance                Torrance Elementary CSR rank: 5
# 965  Torrance                      Torrance High CSR rank: 9
# 966  Torrance                  Towers Elementary CSR rank: 9
# 967  Torrance                  Victor Elementary CSR rank: 9
# 968  Torrance                Walteria Elementary CSR rank: 9
# 969  Torrance                         West High CSR rank: 10
# 970  Torrance                   Yukon Elementary CSR rank: 6
#
#                                  SCHOOL  CSR
# 0                        Alhambra High     8
# 1                         Century High     3
# 2                Emery Park Elementary     7
# 3                   Fremont Elementary     5
# 4                  Garfield Elementary     8
# 5                   Granada Elementary     5
# 6        Alternative Independence High     3
# 7                Marguerita Elementary     7
# 8                     Mark Keppel High    10
# 9            Martha Baldwin Elementary     9
# 10                     Park Elementary     8
# 11                   Ramona Elementary     8
# 12         William Northrup Elementary     7
# 13               Bret Harte Elementary     7
# 14                        Burbank High     8
# 15                      Burroughs High     9
# 16           David Starr Jordan Middle     7
# 17        George Washington Elementary     8
# 18           Joaquin Miller Elementary     9
# 19                    John Muir Middle     8
# 20               Luther Burbank Middle     7
# 21          Continuation Monterey High     2
# 22   Options for Youth-Burbank Charter     4
# 23              Providencia Elementary     7
# 24          R. L. Stevenson Elementary     9
# 25            Ralph Emerson Elementary     8
# 26       Theodore Roosevelt Elementary     9
# 27            Thomas Edison Elementary     9
# 28         Thomas Jefferson Elementary     9
# 29              Walt Disney Elementary     7
# ..                                  ...  ...
# 941                    Anza Elementary    10
# 942               Arlington Elementary     9
# 943                Bert M. Lynn Middle    10
# 944                 Calle Mayor Middle     9
# 945                     Casimir Middle     8
# 946                  Edison Elementary     8
# 947        Edward J. Richardson Middle    10
# 948             Evelyn Carr Elementary     7
# 949                    Fern Elementary     8
# 950                 Hickory Elementary     9
# 951             Howard Wood Elementary     8
# 952                  J. H. Hull Middle     6
# 953                   Jefferson Middle     9
# 954              John Adams Elementary     8
# 955           Joseph Arnold Elementary     9
# 956                 Lincoln Elementary     8
# 957                     Madrona Middle     9
# 958                         North High     9
# 959             Philip Magruder Middle     8
# 960                 Riviera Elementary    10
# 961                 Seaside Elementary    10
# 962  Kurt T. Shery High (Continuation)     3
# 963                         South High    10
# 964                Torrance Elementary     5
# 965                      Torrance High     9
# 966                  Towers Elementary     9
# 967                  Victor Elementary     9
# 968                Walteria Elementary     9
# 969                          West High    10
# 970                   Yukon Elementary     6
#
# [772 rows x 4 columns]

# %%
#Group by City, aggregation average by Gini index

city_csr_df = school_csr_df.groupby(["CITY"])['CSR'].agg(['mean']).sort_index().reset_index()
city_csr_df= city_csr_df.rename(columns={"mean":"CSR_AVG"})

city_csr_df=city_csr_df.sort_values(by='CSR_AVG', ascending=True)
city_csr_df
# Out:
#             CITY   CSR_AVG
# 3      Inglewood  3.419355
# 6       Palmdale  3.550000
# 5    Los Angeles  4.316306
# 7       Pasadena  4.461538
# 4     Long Beach  5.563380
# 0       Alhambra  6.769231
# 2       Glendale  7.250000
# 1        Burbank  7.388889
# 8  Santa Clarita  7.818182
# 9       Torrance  8.090909

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15,7))
sns.barplot(x="CITY", y="CSR_AVG", data=city_csr_df, palette=sns.color_palette("RdYlGn", 10))

plt.xlabel("")
plt.ylabel("CSR AVG")
plt.title("School Ranking by Cities in LA County")

# Save the figure
plt.savefig("../Clean_Data/4.School_Ranking_by_City.png")
plt.show()
