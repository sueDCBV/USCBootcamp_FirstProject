# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns, numpy as np
from itertools import cycle, islice

# %%
##Loading Data in
import pandas as pd
zillow=pd.read_csv('Combined_zillow_data.csv',sep=',', encoding='latin-1')

# %%
##slicing the city_state_zip into columns so I can get the cities out
zillow_subset=zillow['city_state_zip'].apply(lambda x: pd.Series(x.split(' ')))
zillow_subset.columns=['x','City','State','zip','b','q']

# %%
##Getting only City State zip
zillow_subset2=zillow_subset[['City','State','zip']]

# %%
zillow
# Out:
#      Unnamed: 0      zpid                  address      city_state_zip  \
# 0             0  20825166             1010 Omer Ln    Burbank CA 91502
# 1             1  20065948            2601 W Oak St    Burbank CA 91505
# 2             2  20054209   907 E Orange Grove Ave    Burbank CA 91501
# 3             3  20049263         214 S Lincoln St    Burbank CA 91506
# 4             4  20060944          1600 Tulare Ave    Burbank CA 91504
# 5             5  20047601           1516 N Lima St    Burbank CA 91505
# 6             6  20057251    2230 N Buena Vista St    Burbank CA 91504
# 7             7  20055246        532 Birmingham Rd    Burbank CA 91504
# 8             8  20822902        520 E Elmwood Ave    Burbank CA 91501
# 9             9  20060170     3425 Brace Canyon Rd    Burbank CA 91504
# 10           10  20060426           3421 Haven Way    Burbank CA 91504
# 11           11  20051217       1009 N Brighton St    Burbank CA 91506
# 12           12  20054592       1018 E Verdugo Ave    Burbank CA 91501
# 13           13  20033995         9437 Via Monique    Burbank CA 91504
# 14           14  20059331             925 Uclan Dr    Burbank CA 91504
# 15           15  20058053        1801 N Kenneth Rd    Burbank CA 91504
# 16           16  20059627           849 Stephen Rd    Burbank CA 91504
# 17           17  20054059      807 E Magnolia Blvd    Burbank CA 91501
# 18           18  20064293         3100 W Clark Ave    Burbank CA 91505
# 19           19  20055053            737 Tufts Ave    Burbank CA 91504
# 20           20  20051476         910 N Orchard Dr    Burbank CA 91506
# 21           21  20060255          2911 Joaquin Dr    Burbank CA 91504
# 22           22  20058740  1021 N Sunset Canyon Dr    Burbank CA 91504
# 23           23  20056484     2120 N Screenland Dr    Burbank CA 91505
# 24           24  20049151         201 S Orchard Dr    Burbank CA 91506
# 25           25  20049707       341 S Virginia Ave    Burbank CA 91506
# 26           26  20059572          837 Stanford Rd    Burbank CA 91504
# 27           27  20059084          936 Delaware Rd    Burbank CA 91504
# 28           28  20052423        252 W Tujunga Ave    Burbank CA 91502
# 29           29  20065394        347 N Fairview St    Burbank CA 91505
# ..          ...       ...                      ...                 ...
# 515         518  20373793          3462 W 170th St   Torrance CA 90504
# 516         519  20369587            4033 184th St   Torrance CA 90504
# 517         520  21267215       21122 Harvard Blvd   Torrance CA 90501
# 518         521  20373364       17801 Glenburn Ave   Torrance CA 90504
# 519         522  21330789           19417 Anza Ave   Torrance CA 90503
# 520         523  21268629          1551 W 206th St   Torrance CA 90501
# 521         524  21327693              5028 Lee St   Torrance CA 90503
# 522         525  21332168         20357 Madison St   Torrance CA 90503
# 523         526  21267210       21146 Harvard Blvd   Torrance CA 90501
# 524         527  21265724          1349 W 221st St   Torrance CA 90501
# 525         528  21330797          5013 Deelane St   Torrance CA 90503
# 526         529  21344235       3399 Candlewood Rd   Torrance CA 90505
# 526      1975.0      5716          2050.0       4.0       3.00
# 527      1981.0      5812          1918.0       3.0       3.00
# 528      1981.0    176904          1237.0       2.0       3.00
# 529      2005.0     43004          1540.0       3.0       2.00
# 530      1956.0      6098          1140.0       3.0       2.00
# 531      1965.0      6769          2112.0       4.0       3.00
# 532      1975.0      5713          2561.0       5.0       3.00
# 533      1947.0     10977          2557.0       6.0       3.00
# 534      1954.0      6897          1541.0       4.0       2.00
# 535      1979.0      6691          2434.0       4.0       3.00
# 536      1963.0      6290          4271.0       8.0       6.00
# 537      1976.0      6025          2045.0       4.0       2.00
# 538      2004.0    131748          2580.0       4.0       4.00
# 539      1954.0      5200          1616.0       3.0       2.00
# 540      1979.0    174102          1490.0       3.0       3.00
# 541      1954.0     10149          3578.0       7.0       5.00
# 542      1956.0      5000          1283.0       4.0       2.00
# 543      1963.0      8305          1646.0       4.0       2.00
# 544      1955.0      7227          2321.0       4.0       3.00
#
# [545 rows x 18 columns]

# %%
## Adding city state zip back into main data frame
zillow=pd.concat([zillow,zillow_subset2],axis=1)
zillow
# Out:
#      Unnamed: 0      zpid                  address      city_state_zip  \
# 0             0  20825166             1010 Omer Ln    Burbank CA 91502
# 1             1  20065948            2601 W Oak St    Burbank CA 91505
# 2             2  20054209   907 E Orange Grove Ave    Burbank CA 91501
# 3             3  20049263         214 S Lincoln St    Burbank CA 91506
# 4             4  20060944          1600 Tulare Ave    Burbank CA 91504
# 5             5  20047601           1516 N Lima St    Burbank CA 91505
# 6             6  20057251    2230 N Buena Vista St    Burbank CA 91504
# 7             7  20055246        532 Birmingham Rd    Burbank CA 91504
# 8             8  20822902        520 E Elmwood Ave    Burbank CA 91501
# 9             9  20060170     3425 Brace Canyon Rd    Burbank CA 91504
# 10           10  20060426           3421 Haven Way    Burbank CA 91504
# 11           11  20051217       1009 N Brighton St    Burbank CA 91506
# 12           12  20054592       1018 E Verdugo Ave    Burbank CA 91501
# 13           13  20033995         9437 Via Monique    Burbank CA 91504
# 14           14  20059331             925 Uclan Dr    Burbank CA 91504
# 15           15  20058053        1801 N Kenneth Rd    Burbank CA 91504
# 16           16  20059627           849 Stephen Rd    Burbank CA 91504
# 17           17  20054059      807 E Magnolia Blvd    Burbank CA 91501
# 18           18  20064293         3100 W Clark Ave    Burbank CA 91505
# 19           19  20055053            737 Tufts Ave    Burbank CA 91504
# 20           20  20051476         910 N Orchard Dr    Burbank CA 91506
# 21           21  20060255          2911 Joaquin Dr    Burbank CA 91504
# 22           22  20058740  1021 N Sunset Canyon Dr    Burbank CA 91504
# 23           23  20056484     2120 N Screenland Dr    Burbank CA 91505
# 24           24  20049151         201 S Orchard Dr    Burbank CA 91506
# 25           25  20049707       341 S Virginia Ave    Burbank CA 91506
# 26           26  20059572          837 Stanford Rd    Burbank CA 91504
# 27           27  20059084          936 Delaware Rd    Burbank CA 91504
# 28           28  20052423        252 W Tujunga Ave    Burbank CA 91502
# 29           29  20065394        347 N Fairview St    Burbank CA 91505
# ..          ...       ...                      ...                 ...
# 515         518  20373793          3462 W 170th St   Torrance CA 90504
# 19        852028.0  ...         610227.0             2017      1951.0
# 20        854654.0  ...         421617.0             2017      1939.0
# 21        981794.0  ...        1159820.0             2017      1971.0
# 22       1596577.0  ...        1032448.0             2017      1958.0
# 23        602287.0  ...         398137.0             2017      1941.0
# 24        989662.0  ...         504085.0             2017      1947.0
# 25        834528.0  ...         501798.0             2017      1944.0
# 26        890809.0  ...          91156.0             2017      1954.0
# 27        909096.0  ...         131576.0             2017      1952.0
# 28        904831.0  ...         350542.0             2017      1925.0
# 29       1047426.0  ...         887243.0             2017      1926.0
# ..             ...  ...              ...              ...         ...
# 515       625984.0  ...         298597.0             2017      1974.0
# 516       724653.0  ...         642702.0             2017      1954.0
# 517       531246.0  ...         515000.0             2017      1949.0
# 518       674726.0  ...         359565.0             2017      1955.0
# 519       758080.0  ...         337061.0             2017      1954.0
# 520       528651.0  ...         381971.0             2017      1949.0
# 521       965693.0  ...         110872.0             2017      1956.0
# 522       859822.0  ...         772731.0             2017      1964.0
# 523       640600.0  ...         332782.0             2017      1953.0
# 524       489621.0  ...         251864.0             2017      1931.0
# 525       908589.0  ...         379003.0             2017      1955.0
# 526       970715.0  ...         478412.0             2017      1975.0
# 527       623429.0  ...         441464.0             2017      1981.0
# 528       501793.0  ...         461000.0             2017      1981.0
# 529       476737.0  ...         441383.0             2017      2005.0
# 530       830426.0  ...         654223.0             2017      1956.0
# 531       987885.0  ...         481453.0             2017      1965.0
# 532      1041204.0  ...         187574.0             2017      1975.0
# 533      1627180.0  ...         177135.0             2017      1947.0
# 534       722919.0  ...         198950.0             2017      1954.0
# 535      1065463.0  ...         335191.0             2017      1979.0
# 536      1447110.0  ...         201902.0             2017      1963.0
# 537       794687.0  ...         537179.0             2017      1976.0
# 538       880563.0  ...         710406.0             2017      2004.0
# 539       886260.0  ...         261643.0             2017      1954.0
# 540       580384.0  ...         353851.0             2017      1979.0
# 541      1214304.0  ...         565195.0             2017      1954.0
# 542       770957.0  ...         592756.0             2017      1956.0
# 543      1101664.0  ...         286976.0             2017      1963.0
# 544      1200164.0  ...         510994.0             2017      1955.0
#
#      lot size  finished sq ft  bedrooms  bathrooms      City State    zip
# 0        6592          1612.0       4.0       2.00   Burbank    CA  91502
# 1        6267          2161.0       4.0       2.00   Burbank    CA  91505
# 2        7453          1006.0       3.0       1.00   Burbank    CA  91501
# 3        7048          1156.0       2.0       2.00   Burbank    CA  91506
# 4        8578          1431.0       2.0       1.00   Burbank    CA  91504
# 5        6882          1200.0       2.0       1.00   Burbank    CA  91505
# 6        6379           924.0       3.0       1.00   Burbank    CA  91504
# 7        7262          1332.0       3.0       2.00   Burbank    CA  91504
# 8       23395          1743.0       2.0       3.00   Burbank    CA  91501
# 9       10003          2519.0       3.0       3.00   Burbank    CA  91504
# 10      13677          2968.0       4.0       2.50   Burbank    CA  91504
# 11       7198          1565.0       3.0       2.00   Burbank    CA  91506
# 12       7622          1128.0       3.0       1.00   Burbank    CA  91501
# 13     195306          1244.0       2.0       3.00   Burbank    CA  91504
# 14       7380          3464.0       4.0       3.00   Burbank    CA  91504
# 15       6207          1349.0       3.0       1.00   Burbank    CA  91504
# 16      12918          3106.0       4.0       3.00   Burbank    CA  91504
# 17       7548          3510.0       5.0       4.00   Burbank    CA  91501
# 18       8186          1598.0       3.0       3.00   Burbank    CA  91505
# 19       6934          1515.0       3.0       2.00   Burbank    CA  91504
# 20       5623          1670.0       4.0       3.00   Burbank    CA  91506
# 21       7564          2119.0       4.0       2.75   Burbank    CA  91504
# 22      10018          3644.0       4.0       5.00   Burbank    CA  91504
# 23       6751           918.0       2.0       1.00   Burbank    CA  91505
# 24       9449          2103.0       2.0       2.00   Burbank    CA  91506
# 25       7463          1597.0       4.0       2.00   Burbank    CA  91506
# 26       8962          1588.0       3.0       2.00   Burbank    CA  91504
# 27       7429          1671.0       4.0       2.00   Burbank    CA  91504
# 28       7749          1912.0       3.0       2.00   Burbank    CA  91502
# 29       6098          2272.0       4.0       3.00   Burbank    CA  91505
# ..        ...             ...       ...        ...       ...   ...    ...
# 515    116183          1542.0       3.0       3.00  Torrance    CA  90504
# 516      5357          1524.0       4.0       2.00  Torrance    CA  90504
# 517      8491          1313.0       3.0       2.00  Torrance    CA  90501
# 518      5300          1249.0       3.0       2.00  Torrance    CA  90504
# 519      5405          1112.0       3.0       1.00  Torrance    CA  90503
# 520      7013          1419.0       3.0       2.00  Torrance    CA  90501
# 521      6760          2075.0       3.0       2.00  Torrance    CA  90503
# 522      6002          2108.0       4.0       2.00  Torrance    CA  90503
# 523      8491          2404.0       5.0       2.00  Torrance    CA  90501
# 524      6500           754.0       2.0       1.00  Torrance    CA  90501
# 525      5701          1792.0       3.0       2.00  Torrance    CA  90503
# 526      5716          2050.0       4.0       3.00  Torrance    CA  90505
# 527      5812          1918.0       3.0       3.00  Torrance    CA  90504
# 528    176904          1237.0       2.0       3.00  Torrance    CA  90504
# 529     43004          1540.0       3.0       2.00  Torrance    CA  90501
# 530      6098          1140.0       3.0       2.00  Torrance    CA  90503
# 531      6769          2112.0       4.0       3.00  Torrance    CA  90505
# 532      5713          2561.0       5.0       3.00  Torrance    CA  90505
# 533     10977          2557.0       6.0       3.00  Torrance    CA  90505
# 534      6897          1541.0       4.0       2.00  Torrance    CA  90504
# 535      6691          2434.0       4.0       3.00  Torrance    CA  90503
# 536      6290          4271.0       8.0       6.00  Torrance    CA  90503
# 537      6025          2045.0       4.0       2.00  Torrance    CA  90504
# 538    131748          2580.0       4.0       4.00  Torrance    CA  90504
# 539      5200          1616.0       3.0       2.00  Torrance    CA  90503
# 540    174102          1490.0       3.0       3.00  Torrance    CA  90501
# 541     10149          3578.0       7.0       5.00  Torrance    CA  90501
# 542      5000          1283.0       4.0       2.00  Torrance    CA  90505
# 543      8305          1646.0       4.0       2.00  Torrance    CA  90505
# 544      7227          2321.0       4.0       3.00  Torrance    CA  90503
#
# [545 rows x 21 columns]

# %%
#Updating some city names 
zillow.City[zillow.City == '245'] = 'Long Beach' 
#zillow[zillow.City.str.contains('South')==True]
zillow.City[zillow.City == 'South'] = 'Pasadena'
zillow.City[zillow.City == 'Redondo'] = 'Torrance'
zillow.City[zillow.City == 'Los'] = 'Los Angeles'
zillow.City[zillow.City == 'Santa'] = 'Santa Clarita'
zillow.City[zillow.City == 'Long'] = 'Long Beach'
# Out:
# C:\Users\lindsay.yan\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\lindsay.yan\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\lindsay.yan\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\lindsay.yan\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\lindsay.yan\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\lindsay.yan\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
##Getting City Averages for Columns
zillow_gb=zillow.groupby('City').mean()

# %%
##Changing data types so they are more  readable 
zillow_gb.zestimate=zillow_gb.zestimate.astype('long')
zillow_gb.valuation_high=zillow_gb.valuation_high.astype('long')
zillow_gb.valuation_low=zillow_gb.valuation_low.astype('long')
zillow_gb['tax assessment']=zillow_gb['tax assessment'].astype('long')
zillow_gb['tax assess year']=zillow_gb['tax assess year'].astype('int')
zillow_gb['lot size']=zillow_gb['lot size'].astype('long')
zillow_gb['finished sq ft']=zillow_gb['finished sq ft'].astype('long')
zillow_gb['year built']=zillow_gb['year built'].astype('long')
zillow_gb.bedrooms=zillow_gb.bedrooms.astype('int')
zillow_gb.bathrooms=zillow_gb.bathrooms.astype('int')

# %%
zillow_gb_lat_lng=[['latitude','longitude']]

# %%
##Deleting unnecessary columns
del zillow_gb['zpid']
del zillow_gb['latitude']
del zillow_gb['longitude']
del zillow_gb['message_code']

# %%
##Calculating some new measures
zillow_gb['PP_lot']=zillow_gb.zestimate/zillow_gb['lot size']
zillow_gb.PP_lot=zillow_gb.PP_lot.astype('int')
zillow_gb['PP_sqft']=zillow_gb.zestimate/zillow_gb['finished sq ft']
zillow_gb.PP_sqft=zillow_gb.PP_sqft.astype('int')
zillow_gb
# Out:
#                Unnamed: 0  zestimate  valuation_high  valuation_low  \
# City
# Alhambra       192.500000     786966          829426         742117
# Burbank         25.500000    1125583         1189356        1060698
# Glendale        85.000000    1137447         1211146        1063506
# Inglewood      142.500000     717422          798782         667456
# Long Beach     245.500000     635511          679461         594351
# Los Angeles    298.254237     770387          826419         721323
# Palmdale       362.232143     332900          351534         314708
# Pasadena       416.000000    1779256         1903052        1652609
# Santa Clarita  468.500000     759555          806203         712300
# Torrance       521.500000     898269          948236         847996
#
#                tax assessment  tax assess year  year built  lot size  \
# City
# Alhambra               385167             2017        1946     19314
# Burbank                552952             2017        1957     39165
# Glendale               566964             2017        1946     12030
# Inglewood              280203             2017        1949     12584
# Long Beach             357056             2017        1942      7509
# Los Angeles            264671             2017        1929     14589
# Palmdale               231949             2017        1983     18357
# Pasadena               773550             2017        1944     24416
# Santa Clarita          548975             2017        1980     35783
# Torrance               431725             2017        1961     18249
#
#                finished sq ft  bedrooms  bathrooms  PP_lot  PP_sqft
# City
# Alhambra                 1731         2          2      40      454
# Burbank                  2134         3          2      28      527
# Glendale                 2093         3          2      94      543
# Inglewood                1964         3          2      57      365
# Long Beach               1703         3          2      84      373
# Los Angeles              1808         3          2      52      426
# Palmdale                 1940         3          2      18      171
# Pasadena                 5378         3          3      72      330
# Santa Clarita            2401         3          2      21      316
# Torrance                 1900         3          2      49      472

# %%
# Drawing out Average Price Per City

# set the plot x_axis, y_axis, title and label 
sns.set_style("whitegrid")
sns.barplot(x=zillow_gb.index, y="zestimate", data=zillow_gb, palette=sns.color_palette("Set3", 19))

plt.xticks(rotation=90)
plt.ylabel("Price, USD")
plt.title("Average Price Per City")
#plt.show()

# Save the figure
plt.savefig("Average Price Per City.png")

# %%
##Getting city house prices for box and whisker plots 
zillow_box=zillow[['City','zestimate']]

# %%
##Getting city house prices for box and whisker plots 
Glendale=zillow_box[zillow_box['City']=='Glendale']     
Burbank=zillow_box[zillow_box['City']=='Burbank'] 
Inglewood=zillow_box[zillow_box['City']=='Inglewood'] 
Alhambra=zillow_box[zillow_box['City']=='Alhambra'] 
Pasadena=zillow_box[zillow_box['City']=='Pasadena'] 
Long_Beach=zillow_box[zillow_box['City']=='Long Beach'] 
Los_Angeles=zillow_box[zillow_box['City']=='Los Angeles'] 
Palmdale=zillow_box[zillow_box['City']=='Palmdale'] 
Santa_Clarita=zillow_box[zillow_box['City']=='Santa Clarita'] 
Torrance=zillow_box[zillow_box['City']=='Torrance']

# %%
##Getting city house prices for box and whisker plots 
##Getting only 50 per city the cities dont have matching records 
Glendale=Glendale.sample(n=50)
Burbank=Burbank.sample(n=50)
Inglewood=Inglewood.sample(n=50)
Alhambra=Alhambra.sample(n=50)
Pasadena=Pasadena.sample(n=50)
Long_Beach=Long_Beach.sample(n=50)
Los_Angeles=Los_Angeles.sample(n=50)
Palmdale=Palmdale.sample(n=50)
Santa_Clarita=Santa_Clarita.sample(n=50)
Torrance=Torrance.sample(n=50)

# %%
##Getting city house prices for box and whisker plots 
Glendale.columns=['city','Glendal']
Burbank.columns=['city','Burbank']
Inglewood.columns=['city','Inglewood']
Alhambra.columns=['city','Alhambra']
Pasadena.columns=['city','Pasadena']
Long_Beach.columns=['city','Long_Beach']
Los_Angeles.columns=['city','Los_Angeles']
Palmdale.columns=['city','Palmdale']
Santa_Clarita.columns=['city','Santa_Clarita']
Torrance.columns=['city','Torrance']

# %%
##Getting city house prices for box and whisker plots 
Glendale=Glendale.reset_index()
Burbank=Burbank.reset_index()
Inglewood=Inglewood.reset_index()
Alhambra=Alhambra.reset_index()
Pasadena=Pasadena.reset_index()
Long_Beach=Long_Beach.reset_index()
Los_Angeles=Los_Angeles.reset_index()
Palmdale=Palmdale.reset_index()
Santa_Clarita=Santa_Clarita.reset_index()
Torrance=Torrance.reset_index()

# %%
##Getting city house prices for box and whisker plots 
df=pd.concat([Glendale.Glendal
           ,Burbank.Burbank
           ,Inglewood.Inglewood
           ,Alhambra.Alhambra
           ,Pasadena.Pasadena
           ,Long_Beach.Long_Beach
           ,Los_Angeles.Los_Angeles
           ,Palmdale.Palmdale
           ,Santa_Clarita.Santa_Clarita
           ,Torrance.Torrance],axis=1)

# %%
##Drawing the box and whisker plots to see the variances in terms of prices 
import seaborn as sns
from matplotlib import pyplot as plt
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.ylim(0,5000000)
plt.ylabel("Price, USD")
plt.title('House Price Ranges per City')
plt.xticks(rotation=90)
#plt.show()
plt.savefig("House Price Ranges per City.png")

# %%
# Drawing out Average Price Per sqft per City
# set the plot x_axis, y_axis, title and label 
sns.set_style("whitegrid")
sns.barplot(x=zillow_gb.index, y="PP_sqft", data=zillow_gb, palette=sns.color_palette("Set3", 19))

plt.xticks(rotation=90)
plt.ylabel("Price, USD")
plt.title("Average Price Per Squarefeet Per City")
#plt.show()
plt.savefig("Average Price Per Squarefeet Per City.png")

# %%
# Drawing out Average Price Per lot per City
# set the plot x_axis, y_axis, title and label 
sns.set_style("whitegrid")
sns.barplot(x=zillow_gb.index, y="PP_lot", data=zillow_gb, palette=sns.color_palette("Set3", 19))

plt.xticks(rotation=90)
plt.ylabel("Price, USD")
plt.title("Average Price Per lot Per City")
#plt.show()
plt.savefig("Average Price Per lot Per City.png")

# %%
# Drawing out Average year built per City
# set the plot x_axis, y_axis, title and label 
sns.set_style("whitegrid")
sns.barplot(x=zillow_gb.index, y="year built", data=zillow_gb, palette=sns.color_palette("Set3", 19))

plt.xticks(rotation=90)
plt.ylim(1920,1990)
plt.ylabel("Year")
plt.title("Average year built Per City")
#plt.show()
plt.savefig("Average year built Per City.png")

# %%
zillow_gb.head()
zillow_gb['sqft_percentage']=zillow_gb['finished sq ft']/zillow_gb['lot size']

# %%
zillow_gb
# Out:
#                Unnamed: 0  zestimate  valuation_high  valuation_low  \
# City
# Alhambra       192.500000     786966          829426         742117
# Burbank         25.500000    1125583         1189356        1060698
# Glendale        85.000000    1137447         1211146        1063506
# Inglewood      142.500000     717422          798782         667456
# Long Beach     245.500000     635511          679461         594351
# Los Angeles    298.254237     770387          826419         721323
# Palmdale       362.232143     332900          351534         314708
# Pasadena       416.000000    1779256         1903052        1652609
# Santa Clarita  468.500000     759555          806203         712300
# Torrance       521.500000     898269          948236         847996
#
#                tax assessment  tax assess year  year built  lot size  \
# City
# Alhambra               385167             2017        1946     19314
# Burbank                552952             2017        1957     39165
# Glendale               566964             2017        1946     12030
# Inglewood              280203             2017        1949     12584
# Long Beach             357056             2017        1942      7509
# Los Angeles            264671             2017        1929     14589
# Palmdale               231949             2017        1983     18357
# Pasadena               773550             2017        1944     24416
# Santa Clarita          548975             2017        1980     35783
# Torrance               431725             2017        1961     18249
#
#                finished sq ft  bedrooms  bathrooms  PP_lot  PP_sqft  \
# City
# Alhambra                 1731         2          2      40      454
# Burbank                  2134         3          2      28      527
# Glendale                 2093         3          2      94      543
# Inglewood                1964         3          2      57      365
# Long Beach               1703         3          2      84      373
# Los Angeles              1808         3          2      52      426
# Palmdale                 1940         3          2      18      171
# Pasadena                 5378         3          3      72      330
# Santa Clarita            2401         3          2      21      316
# Torrance                 1900         3          2      49      472
#
#                sqft_percentage
# City
# Alhambra              0.089624
# Burbank               0.054487
# Glendale              0.173982
# Inglewood             0.156071
# Long Beach            0.226795
# Los Angeles           0.123929
# Palmdale              0.105682
# Pasadena              0.220265
# Santa Clarita         0.067099
# Torrance              0.104115

# %%
# Drawing out Average Squarefootage Rate
# set the plot x_axis, y_axis, title and label 
sns.set_style("whitegrid")
sns.barplot(x=zillow_gb.index, y="sqft_percentage", data=zillow_gb, palette=sns.color_palette("Set3", 19))

plt.xticks(rotation=90)

plt.ylabel("percentage")
plt.title("Average Squarefootage Rate")
#plt.show()
plt.savefig("Average SQFT Rate.png")
